# %% [markdown]
# # Import libraries

# %%
import os
import cv2
import shutil
import random
import numpy as np
import matplotlib.pyplot as plt

### Other dependencies ###
from PIL import Image
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder

### Tensorflow dependencies ###
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import MeanIoU
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping
from tensorflow.keras.losses import MeanSquaredError, BinaryCrossentropy

### Some constants ###
input_dim = 12 # 48
weights_dir = 'road_signs'
pnet_tensorboard_logdir = 'pnet_logs'
rnet_tensorboard_logdir = 'rnet_logs'
onet_tensorboard_logdir = 'onet_logs'

pnet_weights = f'weights/{weights_dir}/pnet.weights.hdf5'
rnet_weights = f'weights/{weights_dir}/rnet.weights.hdf5'
onet_weights = f'weights/{weights_dir}/onet.weights.hdf5'

if(not os.path.exists(f'weights/{weights_dir}')):
    print('[INFO] Created weight directory ...')
    os.mkdir(f'weights/{weights_dir}')
    
if(os.path.exists(pnet_tensorboard_logdir)):
    print('[INFO] Clearing P-Net log directory ... ')
    shutil.rmtree(pnet_tensorboard_logdir)

if(os.path.exists(rnet_tensorboard_logdir)):
    print('[INFO] Clearing R-Net log directory ... ')
    shutil.rmtree(rnet_tensorboard_logdir)

if(os.path.exists(onet_tensorboard_logdir)):
    print('[INFO] Clearing O-Net log directory ... ')
    shutil.rmtree(onet_tensorboard_logdir)
    
epochs = 500
batch_size = 16
pnet_tensorboard = TensorBoard(log_dir=pnet_tensorboard_logdir)
pnet_checkpoint = ModelCheckpoint(pnet_weights, save_weights_only=True)
pnet_callbacks = [pnet_tensorboard, pnet_checkpoint]

rnet_tensorboard = TensorBoard(log_dir=rnet_tensorboard_logdir)
rnet_checkpoint = ModelCheckpoint(rnet_weights, save_weights_only=True)
rnet_callbacks = [rnet_tensorboard, rnet_checkpoint]

onet_tensorboard = TensorBoard(log_dir=onet_tensorboard_logdir)
onet_checkpoint = ModelCheckpoint(onet_weights, save_weights_only=True)
onet_early_stop1 = EarlyStopping(monitor='val_probability_loss', patience=15, verbose=1)
onet_early_stop2 = EarlyStopping(monitor='val_bbox_regression_loss', patience=15, verbose=1)
onet_callbacks = [onet_tensorboard, onet_checkpoint]

train_dir = "/home/minhhieu/Desktop/Hieu/datasets/RoadSignDetection/images"
test_dir = "/home/minhhieu/Desktop/Hieu/datasets/GTSDB/TestIJCNN2013/TestIJCNN2013Download"
# Out:
# [INFO] Clearing R-Net log directory ...

# %% [markdown]
# # Load and explore dataset

# %%
def load_raw_dataset(dataset_dir, gt_file, delimiter=';', max_n_samples=3000):
    '''
        This function will take in a dataset directory with ppm images (according to the DTSDB dataset)
        then it will return a list where each element is a list of 3 items. First item is the image, the
        second item is the bounding box and the last is the class ID.
        
        Params :
            @dataset_dir : Dataset directory.
            @gt_file : The file that consists of ground truth annotation in the format
            <img_pth>;<left>;<top>;<right>;<bottom>;<class_idx>.
            @delimiter : The separator of each item in each line of the ground truth file
            
        Returns :
            raw_dataset : list of elements [<cv2_img>, <gt_bbox>, <class_idx>]
    '''
    gt_abs_path = os.path.join(dataset_dir, gt_file)
    class_ids = {}
    lines = open(gt_abs_path, 'r').readlines()
    
    print('[INFO] From images to ground truth ... ')
    images_to_gt = [[x.strip().split(delimiter)[0],   # Image path
                     x.strip().split(delimiter)[1:5], # Bbox regression ground truth
                     x.strip().split(delimiter)[5]]   # The class index
                    for x in lines]
    
    print('[INFO] Converting to raw dataset ... ')
    raw_dataset = [[cv2.cvtColor(cv2.imread(os.path.join(dataset_dir, x[0])), cv2.COLOR_BGR2RGB),
                    np.array(x[1]).astype('int'),
                    x[2]] 
                  for x in images_to_gt[:max_n_samples]]
    
    print(f'[INFO] {len(raw_dataset)} samples loaded ... ')
    
    return raw_dataset
    
# raw_dataset = load_raw_dataset(train_dir, 'gt.txt')

# ### Visualize sample data ###
# img = raw_dataset[1][0].copy()
# bbox = raw_dataset[1][1]
# x1, y1, x2, y2 = bbox
# img = cv2.rectangle(img, (x1, y1), (x2, y2), (0,255,0), 2)
# plt.imshow(img)
# plt.show()

# %% [markdown]
# ### Generating negative samples (samples without traffic signs)

# %%
def generate_neg_samples(raw_dataset, frame_per_img=4, crop_size=(48, 48)):
    '''
        This function will generate croppings of fixed size without any traffic sign
        and return those croppings with dummy bbox ground truth
        
        Params:
            @raw_dataset : The raw dataset formated similarly above
            @crop_size : The fixed cropping size
            
        Return:
            neg_samples : A list in format [<crop_img>,<dummy_bbox>,0]
    '''
    neg_samples = []
    for img, bbox, class_id in raw_dataset:
        for i in range(frame_per_img):
            height, width = img.shape[:2]
            x1, y1, x2, y2 = bbox
            range_x = ((0, max(x1 - crop_size[0], 0)), (min(x2 + crop_size[0], width), width))
            range_y = ((0, max(y1 - crop_size[1], 0)), (min(y2 + crop_size[1], height), height))

            ### Generate a random x,y coordinates ###
            x = random.choice([random.randint(range_x[0][0], range_x[0][1]), 
                               random.randint(range_x[1][0], range_x[1][1])])
            y = random.choice([random.randint(range_y[0][0], range_y[0][1]), 
                               random.randint(range_y[1][0], range_y[1][1])])

            # regenerate if cropping does not satisfy the size requirements
            while(width - x < crop_size[0] or height - y < crop_size[1]):
                x = random.choice([random.randint(range_x[0][0], range_x[0][1]), 
                               random.randint(range_x[1][0], range_x[1][1])])
                y = random.choice([random.randint(range_y[0][0], range_y[0][1]), 
                               random.randint(range_y[1][0], range_y[1][1])])

            crop = img[y:y+crop_size[1], x:x+crop_size[0]]
            neg_samples.append([crop, np.array([0,0,0,0]), 0])
        
    print(f'[INFO] {len(neg_samples)} negative samples generated ... ')
    return np.array(neg_samples)

# neg_samples = generate_neg_samples(raw_dataset, crop_size=(input_dim,input_dim))
# plt.imshow(neg_samples[1][0].copy())
# plt.show()

# %% [markdown]
# ### Generate positive samples (samles with traffic signs)

# %%
def generate_pos_samples(raw_dataset, pad_range=(10, 100), frame_per_img=4, img_size=48):
    '''
        This function will generate croppings with traffic signs
        and return those croppings with bbox ground truth
        
        Params:
            @raw_dataset : The raw dataset formated similarly above
            @pad_range : The pad range around the ground truth bounding box
            
        Return:
            pos_samples : A list in format [<crop_img>,<bbox>,1]
    '''
    pos_samples = []
    for img, bbox, class_id in raw_dataset:
        for i in range(frame_per_img):
            height, width = img.shape[:2]
            x1, y1, x2, y2 = bbox
            pad_x1 = min(x1, random.randint(pad_range[0], pad_range[1]))
            pad_x2 = min(width - x2, random.randint(pad_range[0], pad_range[1]))
            pad_y1 = min(y1, random.randint(pad_range[0], pad_range[1]))
            pad_y2 = min(height - y2, random.randint(pad_range[0], pad_range[1]))

            crop = img[y1 - pad_y1:y2 + pad_y2, x1 - pad_x1:x2 + pad_x2]
            h, w = crop.shape[:2]

            gt = np.array([pad_x1, pad_y1, pad_x1 + x2 - x1, pad_y1 + y2 - y1])
            gt[2] = gt[2] - gt[0] # Calculates width
            gt[3] = gt[3] - gt[1] # Calculates height
            gt = np.multiply(gt, np.array([1/w, 1/h, 1/w, 1/h])).astype('float32')

            crop = cv2.resize(crop, (img_size, img_size))
            pos_samples.append([crop, gt, class_id])
        
    print(f'[INFO] {len(pos_samples)} positive samples generated ... ')
    return np.array(pos_samples)

# pos_samples = generate_pos_samples(raw_dataset, pad_range=(5, 15), img_size=input_dim)

# img, gt, label = pos_samples[6]
# img = img.copy()
# h, w = img.shape[:2]
# x1, y1, w, h = np.multiply(gt, np.array([w,h,w,h])).astype('int')

# img = cv2.rectangle(img, (x1, y1), (x1+w, y1+h), 2)
# plt.imshow(img)
# plt.show()

# %% [markdown]
# ### Combine negative and positive samples to form training dataset

# %%
# Generate raw data from firectory
raw_dataset = load_raw_dataset(train_dir, 'gt.txt')
neg_samples = generate_neg_samples(raw_dataset, frame_per_img=4, crop_size=(input_dim,input_dim))
pos_samples = generate_pos_samples(raw_dataset, pad_range=(5, 15), frame_per_img=4, img_size=input_dim)
pos_samples[:, 2] = 1.0
# pos_samples[:,2] = LabelEncoder().fit_transform(pos_samples[:, 2])
# pos_samples[:,2] += 1

# Concatenate two groups and shuffle
train_dataset = np.concatenate([pos_samples, neg_samples])
np.random.shuffle(train_dataset)

train_images = np.array([x[0] for x in train_dataset])
train_bboxes = np.array([x[1] for x in train_dataset])
train_labels = OneHotEncoder().fit_transform(train_dataset[:,2].reshape(-1, 1)).toarray()

train_bboxes = train_bboxes.reshape(-1, 1, 1, 4)
train_labels = train_labels.reshape(-1, 1, 1, train_labels.shape[1])

train_images = ((train_images - 127.5) / 127.5).astype('float32')
train_bboxes = train_bboxes.astype('float32')
train_labels = train_labels.astype('float32')
# Out:
# [INFO] From images to ground truth ...
# [INFO] Converting to raw dataset ...
# [INFO] 1244 samples loaded ...
# [INFO] 4976 negative samples generated ...
# [INFO] 4976 positive samples generated ...

# %% [markdown]
# # Implement P-Net architecture

# %%
def conv_block(in_filters, out_filters, kernel_size=3, batch_norm=False):
    inputs = Input(shape=(None, None, in_filters))
    p_layer = Conv2D(out_filters, kernel_size=kernel_size, strides=(1, 1), padding="valid", kernel_regularizer=l2(2e-4))(inputs)
    if(batch_norm) : p_layer = BatchNormalization()(p_layer)
    p_layer = PReLU(shared_axes=[1, 2])(p_layer)
        
    p_layer = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding="same")(p_layer)
    
    block = Model(inputs = inputs, outputs=p_layer)
    return block

def build_pnet_model(input_shape=None, batch_norm=True, dropout=False, n_classes=2, activation='relu'):
    if(input_shape is not None):
        if(input_shape not in [12, 24, 48, 112, 224]):
            raise Exception('Input shape must be in 12, 24, 48')
    
    inputs = Input(shape=(None, None, 3))
    p_layer = conv_block(3, 10, kernel_size=3, batch_norm=batch_norm)(inputs)
    
    if(input_shape is not None):
        if(input_shape >= 24):
            p_layer = conv_block(10, 10, kernel_size=3, batch_norm=batch_norm)(p_layer)
    
    if(input_shape is not None):
        if(input_shape >= 48):
            p_layer = conv_block(10, 10, kernel_size=3, batch_norm=batch_norm)(p_layer)
            
    if(input_shape is not None):
        if(input_shape >= 112):
            p_layer = conv_block(10, 10, kernel_size=3, batch_norm=batch_norm)(p_layer)

    p_layer = Conv2D(16, kernel_size=(3, 3), strides=(1, 1), padding="valid", kernel_regularizer=l2(2e-4))(p_layer)
    p_layer = PReLU(shared_axes=[1, 2])(p_layer)
        
    p_layer = Conv2D(32, kernel_size=(3, 3), strides=(1, 1), padding="valid", kernel_regularizer=l2(2e-4))(p_layer)
    p_layer = PReLU(shared_axes=[1, 2])(p_layer)
    if(dropout) : p_layer = Dropout(0.5)(p_layer)

    p_layer_out1 = Conv2D(n_classes, kernel_size=(1, 1), strides=(2, 2))(p_layer)
    p_layer_out1 = Softmax(axis=3, name='probability')(p_layer_out1)
    p_layer_out2 = Conv2D(4, kernel_size=(1, 1), strides=(2, 2), activation='sigmoid', name='bbox_regression')(p_layer)

    p_net = Model(inputs, [p_layer_out1, p_layer_out2], name='P-Net')

    return p_net

n_classes = train_labels.shape[3]
pnet = build_pnet_model(input_shape=input_dim, batch_norm=True, dropout=True,
                        n_classes=n_classes)
print(pnet(tf.random.normal((1,input_dim,input_dim,3)))[1].shape)
print(pnet.summary())
# Out:
# (1, 1, 1, 4)
# Model: "P-Net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_33 (InputLayer)           [(None, None, None,  0
# __________________________________________________________________________________________________
# functional_43 (Functional)      (None, None, None, 1 330         input_33[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, None, None, 1 1456        functional_43[0][0]
# __________________________________________________________________________________________________
# p_re_lu_44 (PReLU)              (None, None, None, 1 16          conv2d_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, None, None, 3 4640        p_re_lu_44[0][0]
# __________________________________________________________________________________________________
# p_re_lu_45 (PReLU)              (None, None, None, 3 32          conv2d_56[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, None, None, 3 0           p_re_lu_45[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, None, None, 2 66          dropout_11[0][0]
# __________________________________________________________________________________________________
# probability (Softmax)           (None, None, None, 2 0           conv2d_57[0][0]
# __________________________________________________________________________________________________
# bbox_regression (Conv2D)        (None, None, None, 4 132         dropout_11[0][0]
# ==================================================================================================
# Total params: 6,672
# Trainable params: 6,652
# Non-trainable params: 20
# __________________________________________________________________________________________________
# None

# %% [markdown]
# # Start training P-Net

# %%
losses = {
    'probability' : BinaryCrossentropy(from_logits=False),
    'bbox_regression' : tfa.losses.GIoULoss() # MeanSquaredError(reduction=tf.keras.losses.Reduction.AUTO)
}

y = {
    'probability' : train_labels,
    'bbox_regression' : train_bboxes
}

if(os.path.exists(pnet_weights)):
    print('[INFO] Loading P-Net pretrained weights ...')
    pnet.load_weights(pnet_weights)
pnet.compile(optimizer=Adam(lr=0.00001, amsgrad=True),
            loss=losses,
            metrics={'probability':'accuracy'})
# Out:
# [INFO] Loading P-Net pretrained weights ...

# %%
history = pnet.fit(train_images, y, epochs=epochs, batch_size=batch_size, callbacks=pnet_callbacks)
# Out:
# Epoch 1/500
#   1/622 [..............................] - ETA: 0s - loss: 0.6447 - probability_loss: 0.0082 - bbox_regression_loss: 0.6279 - probability_accuracy: 1.0000WARNING:tensorflow:From /home/minhhieu/.local/lib/python3.8/site-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0024s vs `on_train_batch_end` time: 0.0101s). Check your callbacks.
# 622/622 [==============================] - 1s 2ms/step - loss: 0.8129 - probability_loss: 0.0642 - bbox_regression_loss: 0.7402 - probability_accuracy: 0.9799
# Epoch 2/500
# 622/622 [==============================] - 1s 2ms/step - loss: 0.8086 - probability_loss: 0.0615 - bbox_regression_loss: 0.7385 - probability_accuracy: 0.9803
# Epoch 3/500
# 622/622 [==============================] - 1s 2ms/step - loss: 0.8045 - probability_loss: 0.0574 - bbox_regression_loss: 0.7385 - probability_accuracy: 0.9814
# Epoch 4/500
# 622/622 [==============================] - 1s 2ms/step - loss: 0.8096 - probability_loss: 0.0641 - bbox_regression_loss: 0.7369 - probability_accuracy: 0.9781
# Epoch 5/500
# 622/622 [==============================] - 1s 2ms/step - loss: 0.8057 - probability_loss: 0.0613 - bbox_regression_loss: 0.7358 - probability_accuracy: 0.9806
# Epoch 6/500
# 622/622 [==============================] - 1s 2ms/step - loss: 0.8029 - probability_loss: 0.0574 - bbox_regression_loss: 0.7369 - probability_accuracy: 0.9804
# Epoch 7/500
# 622/622 [==============================] - 1s 2ms/step - loss: 0.8024 - probability_loss: 0.0576 - bbox_regression_loss: 0.7362 - probability_accuracy: 0.9804
# Epoch 8/500
# 622/622 [==============================] - 1s 2ms/step - loss: 0.8001 - probability_loss: 0.0563 - bbox_regression_loss: 0.7352 - probability_accuracy: 0.9810
# Epoch 9/500
# 622/622 [==============================] - 1s 2ms/step - loss: 0.7970 - probability_loss: 0.0531 - bbox_regression_loss: 0.7354 - probability_accuracy: 0.9829
# Epoch 10/500
#   1/622 [..............................] - ETA: 0s - loss: 0.7816 - probability_loss: 0.0067 - bbox_regression_loss: 0.7664 - probability_accuracy: 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-77f824b991a1> in <module>
# ----> 1 history = pnet.fit(train_images, y, epochs=epochs, batch_size=batch_size, callbacks=pnet_callbacks)
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1841       `args` and `kwargs`.
#    1842     """
# -> 1843     return self._call_flat(
#    1844         [t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1845          if isinstance(t, (ops.Tensor,
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1921         and executing_eagerly):
#    1922       # No tape is watching; skip to running the function.
# -> 1923       return self._build_call_outputs(self._inference_function.call(
#    1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     543       with _InterpolateFunctionError(self):
#     544         if cancellation_manager is None:
# --> 545           outputs = execute.execute(
#     546               str(self.signature.name),
#     547               num_outputs=self._num_outputs,
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# # Start training R-Net

# %%
# Generate raw data from firectory
raw_dataset = load_raw_dataset(train_dir, 'gt.txt')
neg_samples = generate_neg_samples(raw_dataset, frame_per_img=6, crop_size=(input_dim*2,input_dim*2))
pos_samples = generate_pos_samples(raw_dataset, pad_range=(10, 30), frame_per_img=3, img_size=input_dim*2)
pos_samples[:, 2] = 1.0
# pos_samples[:,2] = LabelEncoder().fit_transform(pos_samples[:, 2])
# pos_samples[:,2] += 1

# Concatenate two groups and shuffle
train_dataset = np.concatenate([pos_samples, neg_samples])
np.random.shuffle(train_dataset)

train_images = np.array([x[0] for x in train_dataset])
train_bboxes = np.array([x[1] for x in train_dataset])
train_labels = OneHotEncoder().fit_transform(train_dataset[:,2].reshape(-1, 1)).toarray()

train_bboxes = train_bboxes.reshape(-1, 1, 1, 4)
train_labels = train_labels.reshape(-1, 1, 1, train_labels.shape[1])

train_images = ((train_images - 127.5) / 127.5).astype('float32')
train_bboxes = train_bboxes.astype('float32')
train_labels = train_labels.astype('float32')

losses = {
    'probability' : BinaryCrossentropy(from_logits=False),
    'bbox_regression' : tfa.losses.GIoULoss() 
    # 'bbox_regression' : MeanSquaredError(reduction=tf.keras.losses.Reduction.AUTO)
}

y = {
    'probability' : train_labels,
    'bbox_regression' : train_bboxes
}

rnet = build_pnet_model(input_shape=input_dim*2, batch_norm=True, dropout=True, n_classes=n_classes)
print(rnet.summary())

#if(os.path.exists(rnet_weights)):
#    print('[INFO] Loading P-Net pretrained weights ...')
#    rnet.load_weights(rnet_weights)
rnet.compile(optimizer=Adam(lr=0.00001, amsgrad=True),
            loss=losses,
            metrics={'probability':'accuracy'})

history = rnet.fit(train_images, y, epochs=epochs, batch_size=batch_size, callbacks=rnet_callbacks)
# Out:
# [INFO] From images to ground truth ...
# [INFO] Converting to raw dataset ...
# [INFO] 1244 samples loaded ...
# [INFO] 7464 negative samples generated ...
# [INFO] 3732 positive samples generated ...
# Model: "P-Net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_35 (InputLayer)           [(None, None, None,  0
# __________________________________________________________________________________________________
# functional_45 (Functional)      (None, None, None, 1 330         input_35[0][0]
# __________________________________________________________________________________________________
# functional_47 (Functional)      (None, None, None, 1 960         functional_45[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, None, None, 1 1456        functional_47[0][0]
# __________________________________________________________________________________________________
# p_re_lu_48 (PReLU)              (None, None, None, 1 16          conv2d_60[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, None, None, 3 4640        p_re_lu_48[0][0]
# __________________________________________________________________________________________________
# p_re_lu_49 (PReLU)              (None, None, None, 3 32          conv2d_61[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, None, None, 3 0           p_re_lu_49[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, None, None, 2 66          dropout_12[0][0]
# __________________________________________________________________________________________________
# probability (Softmax)           (None, None, None, 2 0           conv2d_62[0][0]
# __________________________________________________________________________________________________
# bbox_regression (Conv2D)        (None, None, None, 4 132         dropout_12[0][0]
# ==================================================================================================
# Total params: 7,632
# Trainable params: 7,592
# Non-trainable params: 40
# __________________________________________________________________________________________________
# None
# Epoch 1/500
#   2/700 [..............................] - ETA: 19s - loss: 2.5300 - probability_loss: 0.7377 - bbox_regression_loss: 1.7826 - probability_accuracy: 0.4688WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0034s vs `on_train_batch_end` time: 0.0525s). Check your callbacks.
# 700/700 [==============================] - 2s 3ms/step - loss: 2.4268 - probability_loss: 0.6666 - bbox_regression_loss: 1.7505 - probability_accuracy: 0.6673
# Epoch 2/500
# 700/700 [==============================] - 2s 3ms/step - loss: 2.3463 - probability_loss: 0.6057 - bbox_regression_loss: 1.7310 - probability_accuracy: 0.7518
# Epoch 3/500
# 700/700 [==============================] - 2s 2ms/step - loss: 2.2308 - probability_loss: 0.5029 - bbox_regression_loss: 1.7182 - probability_accuracy: 0.8005
# Epoch 4/500
# 700/700 [==============================] - 2s 3ms/step - loss: 2.1303 - probability_loss: 0.4091 - bbox_regression_loss: 1.7116 - probability_accuracy: 0.8279
# Epoch 5/500
# 700/700 [==============================] - 2s 2ms/step - loss: 2.0711 - probability_loss: 0.3561 - bbox_regression_loss: 1.7053 - probability_accuracy: 0.8507
# Epoch 6/500
# 700/700 [==============================] - 2s 2ms/step - loss: 2.0275 - probability_loss: 0.3205 - bbox_regression_loss: 1.6973 - probability_accuracy: 0.8650
# Epoch 7/500
# 700/700 [==============================] - 2s 3ms/step - loss: 2.0081 - probability_loss: 0.3049 - bbox_regression_loss: 1.6935 - probability_accuracy: 0.8754
# Epoch 8/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.9933 - probability_loss: 0.2915 - bbox_regression_loss: 1.6922 - probability_accuracy: 0.8821
# Epoch 9/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.9853 - probability_loss: 0.2883 - bbox_regression_loss: 1.6874 - probability_accuracy: 0.8787
# Epoch 10/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.9778 - probability_loss: 0.2815 - bbox_regression_loss: 1.6867 - probability_accuracy: 0.8817
# Epoch 11/500
# 700/700 [==============================] - 2s 2ms/step - loss: 1.9658 - probability_loss: 0.2704 - bbox_regression_loss: 1.6858 - probability_accuracy: 0.8882
# Epoch 12/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.9632 - probability_loss: 0.2689 - bbox_regression_loss: 1.6847 - probability_accuracy: 0.8856
# Epoch 13/500
# 700/700 [==============================] - 2s 2ms/step - loss: 1.9605 - probability_loss: 0.2667 - bbox_regression_loss: 1.6842 - probability_accuracy: 0.8897
# Epoch 14/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.9508 - probability_loss: 0.2572 - bbox_regression_loss: 1.6840 - probability_accuracy: 0.8908
# Epoch 15/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.9462 - probability_loss: 0.2530 - bbox_regression_loss: 1.6836 - probability_accuracy: 0.8947
# Epoch 16/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.9442 - probability_loss: 0.2530 - bbox_regression_loss: 1.6816 - probability_accuracy: 0.8934
# Epoch 17/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.9372 - probability_loss: 0.2470 - bbox_regression_loss: 1.6806 - probability_accuracy: 0.8976
# Epoch 18/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.9404 - probability_loss: 0.2496 - bbox_regression_loss: 1.6813 - probability_accuracy: 0.8976
# Epoch 19/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.9348 - probability_loss: 0.2439 - bbox_regression_loss: 1.6813 - probability_accuracy: 0.9008
# Epoch 20/500
# 700/700 [==============================] - 2s 2ms/step - loss: 1.9304 - probability_loss: 0.2408 - bbox_regression_loss: 1.6800 - probability_accuracy: 0.9026
# Epoch 21/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.9256 - probability_loss: 0.2373 - bbox_regression_loss: 1.6787 - probability_accuracy: 0.9025
# Epoch 22/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.9178 - probability_loss: 0.2286 - bbox_regression_loss: 1.6796 - probability_accuracy: 0.9050
# Epoch 23/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.9186 - probability_loss: 0.2296 - bbox_regression_loss: 1.6794 - probability_accuracy: 0.9087
# Epoch 24/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.9197 - probability_loss: 0.2311 - bbox_regression_loss: 1.6790 - probability_accuracy: 0.9043
# Epoch 25/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.9155 - probability_loss: 0.2264 - bbox_regression_loss: 1.6795 - probability_accuracy: 0.9062
# Epoch 26/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.9087 - probability_loss: 0.2224 - bbox_regression_loss: 1.6768 - probability_accuracy: 0.9120
# Epoch 27/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.9074 - probability_loss: 0.2205 - bbox_regression_loss: 1.6773 - probability_accuracy: 0.9131
# Epoch 28/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.9046 - probability_loss: 0.2178 - bbox_regression_loss: 1.6773 - probability_accuracy: 0.9126
# Epoch 29/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.8973 - probability_loss: 0.2108 - bbox_regression_loss: 1.6769 - probability_accuracy: 0.9151
# Epoch 30/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.9048 - probability_loss: 0.2171 - bbox_regression_loss: 1.6781 - probability_accuracy: 0.9116
# Epoch 31/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.8959 - probability_loss: 0.2092 - bbox_regression_loss: 1.6771 - probability_accuracy: 0.9164
# Epoch 32/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.8961 - probability_loss: 0.2096 - bbox_regression_loss: 1.6769 - probability_accuracy: 0.9187
# Epoch 33/500
# 700/700 [==============================] - 2s 2ms/step - loss: 1.8932 - probability_loss: 0.2073 - bbox_regression_loss: 1.6764 - probability_accuracy: 0.9174
# Epoch 34/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.8854 - probability_loss: 0.1987 - bbox_regression_loss: 1.6771 - probability_accuracy: 0.9215
# Epoch 35/500
# 700/700 [==============================] - 2s 2ms/step - loss: 1.8835 - probability_loss: 0.1979 - bbox_regression_loss: 1.6760 - probability_accuracy: 0.9229
# Epoch 36/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.8829 - probability_loss: 0.1982 - bbox_regression_loss: 1.6752 - probability_accuracy: 0.9212
# Epoch 37/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.8790 - probability_loss: 0.1939 - bbox_regression_loss: 1.6755 - probability_accuracy: 0.9250
# Epoch 38/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.8754 - probability_loss: 0.1898 - bbox_regression_loss: 1.6760 - probability_accuracy: 0.9276
# Epoch 39/500
# 700/700 [==============================] - 2s 2ms/step - loss: 1.8745 - probability_loss: 0.1895 - bbox_regression_loss: 1.6755 - probability_accuracy: 0.9261
# Epoch 40/500
# 700/700 [==============================] - 2s 2ms/step - loss: 1.8678 - probability_loss: 0.1828 - bbox_regression_loss: 1.6755 - probability_accuracy: 0.9289
# Epoch 41/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.8675 - probability_loss: 0.1816 - bbox_regression_loss: 1.6764 - probability_accuracy: 0.9303
# Epoch 42/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.8713 - probability_loss: 0.1864 - bbox_regression_loss: 1.6753 - probability_accuracy: 0.9293
# Epoch 43/500
# 700/700 [==============================] - 2s 2ms/step - loss: 1.8608 - probability_loss: 0.1769 - bbox_regression_loss: 1.6743 - probability_accuracy: 0.9336
# Epoch 44/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.8597 - probability_loss: 0.1752 - bbox_regression_loss: 1.6750 - probability_accuracy: 0.9344
# Epoch 45/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.8618 - probability_loss: 0.1761 - bbox_regression_loss: 1.6762 - probability_accuracy: 0.9330
# Epoch 46/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.8616 - probability_loss: 0.1772 - bbox_regression_loss: 1.6748 - probability_accuracy: 0.9342
# Epoch 47/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.8546 - probability_loss: 0.1697 - bbox_regression_loss: 1.6754 - probability_accuracy: 0.9347
# Epoch 48/500
# 700/700 [==============================] - 2s 2ms/step - loss: 1.8517 - probability_loss: 0.1668 - bbox_regression_loss: 1.6754 - probability_accuracy: 0.9343
# Epoch 49/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.8464 - probability_loss: 0.1619 - bbox_regression_loss: 1.6750 - probability_accuracy: 0.9406
# Epoch 50/500
# 700/700 [==============================] - 2s 3ms/step - loss: 1.8526 - probability_loss: 0.1681 - bbox_regression_loss: 1.6750 - probability_accuracy: 0.9403
# Epoch 51/500
# 189/700 [=======>......................] - ETA: 1s - loss: 1.8521 - probability_loss: 0.1664 - bbox_regression_loss: 1.6762 - probability_accuracy: 0.9372

# %% [markdown]
# # Training O-Net

# %%
# Generate raw data from firectory
raw_dataset = load_raw_dataset(train_dir, 'gt.txt')
neg_samples = generate_neg_samples(raw_dataset, frame_per_img=6, crop_size=(input_dim*4,input_dim*4))
pos_samples = generate_pos_samples(raw_dataset, pad_range=(10, 30), frame_per_img=4, img_size=input_dim*4)
pos_samples[:, 2] = 1.0

# Concatenate two groups and shuffle
train_dataset = np.concatenate([pos_samples, neg_samples])
np.random.shuffle(train_dataset)

train_images = np.array([x[0] for x in train_dataset])
train_bboxes = np.array([x[1] for x in train_dataset])
train_labels = OneHotEncoder().fit_transform(train_dataset[:,2].reshape(-1, 1)).toarray()

train_bboxes = train_bboxes.reshape(-1, 1, 1, 4)
train_labels = train_labels.reshape(-1, 1, 1, train_labels.shape[1])

train_images = ((train_images - 127.5) / 127.5).astype('float32')
train_bboxes = train_bboxes.astype('float32')
train_labels = train_labels.astype('float32')

losses = {
    'probability' : BinaryCrossentropy(from_logits=False),
    'bbox_regression' : tfa.losses.GIoULoss() 
}

y = {
    'probability' : train_labels,
    'bbox_regression' : train_bboxes
}

onet = build_pnet_model(input_shape=input_dim*4, batch_norm=True, dropout=True, n_classes=n_classes)
print(onet.summary())

#if(os.path.exists(onet_weights)):
#    print('[INFO] Loading O-Net pretrained weights ...')
#    onet.load_weights(onet_weights)
onet.compile(optimizer=Adam(lr=0.00001, amsgrad=True),
            loss=losses,
            metrics={'probability':'accuracy'})

history = onet.fit(train_images, y, epochs=epochs, validation_split=0.2, batch_size=batch_size, callbacks=rnet_callbacks)
# Out:
# [INFO] From images to ground truth ...
# [INFO] Converting to raw dataset ...
# [INFO] 1244 samples loaded ...
# [INFO] 7464 negative samples generated ...
# [INFO] 4976 positive samples generated ...
# Model: "P-Net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# functional_3 (Functional)       (None, None, None, 1 330         input_3[0][0]
# __________________________________________________________________________________________________
# functional_5 (Functional)       (None, None, None, 1 960         functional_3[0][0]
# __________________________________________________________________________________________________
# functional_7 (Functional)       (None, None, None, 1 960         functional_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, None, None, 1 1456        functional_7[0][0]
# __________________________________________________________________________________________________
# p_re_lu_6 (PReLU)               (None, None, None, 1 16          conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, None, None, 3 4640        p_re_lu_6[0][0]
# __________________________________________________________________________________________________
# p_re_lu_7 (PReLU)               (None, None, None, 3 32          conv2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, None, None, 3 0           p_re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, None, None, 2 66          dropout_1[0][0]
# __________________________________________________________________________________________________
# probability (Softmax)           (None, None, None, 2 0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# bbox_regression (Conv2D)        (None, None, None, 4 132         dropout_1[0][0]
# ==================================================================================================
# Total params: 8,592
# Trainable params: 8,532
# Non-trainable params: 60
# __________________________________________________________________________________________________
# None
# Epoch 1/500
#   1/622 [..............................] - ETA: 0s - loss: 2.3083 - probability_loss: 0.6787 - bbox_regression_loss: 1.6179 - probability_accuracy: 0.4375WARNING:tensorflow:From /home/minhhieu/.local/lib/python3.8/site-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0036s vs `on_train_batch_end` time: 0.0138s). Check your callbacks.
# 622/622 [==============================] - 2s 3ms/step - loss: 2.4506 - probability_loss: 0.6986 - bbox_regression_loss: 1.7403 - probability_accuracy: 0.5126 - val_loss: 2.3911 - val_probability_loss: 0.6381 - val_bbox_regression_loss: 1.7412 - val_probability_accuracy: 0.6507
# Epoch 2/500
# 622/622 [==============================] - 2s 3ms/step - loss: 2.3492 - probability_loss: 0.6101 - bbox_regression_loss: 1.7273 - probability_accuracy: 0.6873 - val_loss: 2.2889 - val_probability_loss: 0.5534 - val_bbox_regression_loss: 1.7237 - val_probability_accuracy: 0.7801
# Epoch 3/500
# 622/622 [==============================] - 2s 3ms/step - loss: 2.2592 - probability_loss: 0.5429 - bbox_regression_loss: 1.7046 - probability_accuracy: 0.7594 - val_loss: 2.1982 - val_probability_loss: 0.4818 - val_bbox_regression_loss: 1.7047 - val_probability_accuracy: 0.7922
# Epoch 4/500
# 622/622 [==============================] - 2s 3ms/step - loss: 2.1816 - probability_loss: 0.5039 - bbox_regression_loss: 1.6660 - probability_accuracy: 0.7728 - val_loss: 2.0900 - val_probability_loss: 0.4322 - val_bbox_regression_loss: 1.6460 - val_probability_accuracy: 0.8079
# Epoch 5/500
# 622/622 [==============================] - 2s 3ms/step - loss: 2.0783 - probability_loss: 0.4717 - bbox_regression_loss: 1.5949 - probability_accuracy: 0.7871 - val_loss: 1.9351 - val_probability_loss: 0.4004 - val_bbox_regression_loss: 1.5229 - val_probability_accuracy: 0.8179
# Epoch 6/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.9652 - probability_loss: 0.4606 - bbox_regression_loss: 1.4928 - probability_accuracy: 0.7868 - val_loss: 1.7786 - val_probability_loss: 0.3856 - val_bbox_regression_loss: 1.3812 - val_probability_accuracy: 0.8236
# Epoch 7/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.8820 - probability_loss: 0.4668 - bbox_regression_loss: 1.4034 - probability_accuracy: 0.7846 - val_loss: 1.6570 - val_probability_loss: 0.3761 - val_bbox_regression_loss: 1.2691 - val_probability_accuracy: 0.8215
# Epoch 8/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.7882 - probability_loss: 0.4671 - bbox_regression_loss: 1.3093 - probability_accuracy: 0.7859 - val_loss: 1.5343 - val_probability_loss: 0.3645 - val_bbox_regression_loss: 1.1580 - val_probability_accuracy: 0.8280
# Epoch 9/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.6954 - probability_loss: 0.4713 - bbox_regression_loss: 1.2123 - probability_accuracy: 0.7749 - val_loss: 1.4120 - val_probability_loss: 0.3550 - val_bbox_regression_loss: 1.0452 - val_probability_accuracy: 0.8288
# Epoch 10/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.6400 - probability_loss: 0.4773 - bbox_regression_loss: 1.1508 - probability_accuracy: 0.7735 - val_loss: 1.3475 - val_probability_loss: 0.3448 - val_bbox_regression_loss: 0.9908 - val_probability_accuracy: 0.8372
# Epoch 11/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.5995 - probability_loss: 0.4793 - bbox_regression_loss: 1.1083 - probability_accuracy: 0.7751 - val_loss: 1.3175 - val_probability_loss: 0.3330 - val_bbox_regression_loss: 0.9726 - val_probability_accuracy: 0.8457
# Epoch 12/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.5561 - probability_loss: 0.4533 - bbox_regression_loss: 1.0909 - probability_accuracy: 0.7861 - val_loss: 1.2995 - val_probability_loss: 0.3272 - val_bbox_regression_loss: 0.9604 - val_probability_accuracy: 0.8465
# Epoch 13/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.5378 - probability_loss: 0.4548 - bbox_regression_loss: 1.0712 - probability_accuracy: 0.7899 - val_loss: 1.2878 - val_probability_loss: 0.3195 - val_bbox_regression_loss: 0.9564 - val_probability_accuracy: 0.8537
# Epoch 14/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.5164 - probability_loss: 0.4432 - bbox_regression_loss: 1.0614 - probability_accuracy: 0.7929 - val_loss: 1.2793 - val_probability_loss: 0.3148 - val_bbox_regression_loss: 0.9526 - val_probability_accuracy: 0.8589
# Epoch 15/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.4882 - probability_loss: 0.4300 - bbox_regression_loss: 1.0463 - probability_accuracy: 0.7966 - val_loss: 1.2738 - val_probability_loss: 0.3095 - val_bbox_regression_loss: 0.9524 - val_probability_accuracy: 0.8605
# Epoch 16/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.4717 - probability_loss: 0.4199 - bbox_regression_loss: 1.0399 - probability_accuracy: 0.7994 - val_loss: 1.2660 - val_probability_loss: 0.3072 - val_bbox_regression_loss: 0.9468 - val_probability_accuracy: 0.8613
# Epoch 17/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.4567 - probability_loss: 0.4133 - bbox_regression_loss: 1.0315 - probability_accuracy: 0.8084 - val_loss: 1.2601 - val_probability_loss: 0.3040 - val_bbox_regression_loss: 0.9442 - val_probability_accuracy: 0.8641
# Epoch 18/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.4414 - probability_loss: 0.4064 - bbox_regression_loss: 1.0231 - probability_accuracy: 0.8110 - val_loss: 1.2564 - val_probability_loss: 0.2987 - val_bbox_regression_loss: 0.9458 - val_probability_accuracy: 0.8654
# Epoch 19/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.4271 - probability_loss: 0.4000 - bbox_regression_loss: 1.0151 - probability_accuracy: 0.8139 - val_loss: 1.2509 - val_probability_loss: 0.2954 - val_bbox_regression_loss: 0.9436 - val_probability_accuracy: 0.8658
# Epoch 20/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.4242 - probability_loss: 0.4010 - bbox_regression_loss: 1.0113 - probability_accuracy: 0.8160 - val_loss: 1.2457 - val_probability_loss: 0.2907 - val_bbox_regression_loss: 0.9431 - val_probability_accuracy: 0.8662
# Epoch 21/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.4062 - probability_loss: 0.3909 - bbox_regression_loss: 1.0034 - probability_accuracy: 0.8214 - val_loss: 1.2430 - val_probability_loss: 0.2885 - val_bbox_regression_loss: 0.9426 - val_probability_accuracy: 0.8694
# Epoch 22/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.3910 - probability_loss: 0.3792 - bbox_regression_loss: 0.9998 - probability_accuracy: 0.8240 - val_loss: 1.2386 - val_probability_loss: 0.2863 - val_bbox_regression_loss: 0.9404 - val_probability_accuracy: 0.8702
# Epoch 23/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.3978 - probability_loss: 0.3877 - bbox_regression_loss: 0.9981 - probability_accuracy: 0.8200 - val_loss: 1.2352 - val_probability_loss: 0.2827 - val_bbox_regression_loss: 0.9405 - val_probability_accuracy: 0.8690
# Epoch 24/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.3799 - probability_loss: 0.3746 - bbox_regression_loss: 0.9934 - probability_accuracy: 0.8286 - val_loss: 1.2323 - val_probability_loss: 0.2800 - val_bbox_regression_loss: 0.9403 - val_probability_accuracy: 0.8714
# Epoch 25/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.3680 - probability_loss: 0.3669 - bbox_regression_loss: 0.9890 - probability_accuracy: 0.8306 - val_loss: 1.2279 - val_probability_loss: 0.2790 - val_bbox_regression_loss: 0.9369 - val_probability_accuracy: 0.8734
# Epoch 26/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.3590 - probability_loss: 0.3611 - bbox_regression_loss: 0.9859 - probability_accuracy: 0.8336 - val_loss: 1.2250 - val_probability_loss: 0.2749 - val_bbox_regression_loss: 0.9381 - val_probability_accuracy: 0.8718
# Epoch 27/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.3465 - probability_loss: 0.3527 - bbox_regression_loss: 0.9817 - probability_accuracy: 0.8371 - val_loss: 1.2220 - val_probability_loss: 0.2728 - val_bbox_regression_loss: 0.9372 - val_probability_accuracy: 0.8746
# Epoch 28/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.3443 - probability_loss: 0.3525 - bbox_regression_loss: 0.9797 - probability_accuracy: 0.8372 - val_loss: 1.2190 - val_probability_loss: 0.2718 - val_bbox_regression_loss: 0.9351 - val_probability_accuracy: 0.8742
# Epoch 29/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.3399 - probability_loss: 0.3512 - bbox_regression_loss: 0.9766 - probability_accuracy: 0.8400 - val_loss: 1.2163 - val_probability_loss: 0.2683 - val_bbox_regression_loss: 0.9360 - val_probability_accuracy: 0.8750
# Epoch 30/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.3342 - probability_loss: 0.3462 - bbox_regression_loss: 0.9760 - probability_accuracy: 0.8412 - val_loss: 1.2139 - val_probability_loss: 0.2666 - val_bbox_regression_loss: 0.9352 - val_probability_accuracy: 0.8770
# Epoch 31/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.3244 - probability_loss: 0.3402 - bbox_regression_loss: 0.9721 - probability_accuracy: 0.8458 - val_loss: 1.2106 - val_probability_loss: 0.2655 - val_bbox_regression_loss: 0.9330 - val_probability_accuracy: 0.8778
# Epoch 32/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.3234 - probability_loss: 0.3408 - bbox_regression_loss: 0.9705 - probability_accuracy: 0.8443 - val_loss: 1.2077 - val_probability_loss: 0.2630 - val_bbox_regression_loss: 0.9326 - val_probability_accuracy: 0.8778
# Epoch 33/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.3148 - probability_loss: 0.3324 - bbox_regression_loss: 0.9703 - probability_accuracy: 0.8471 - val_loss: 1.2064 - val_probability_loss: 0.2604 - val_bbox_regression_loss: 0.9339 - val_probability_accuracy: 0.8802
# Epoch 34/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.3138 - probability_loss: 0.3350 - bbox_regression_loss: 0.9667 - probability_accuracy: 0.8456 - val_loss: 1.2040 - val_probability_loss: 0.2581 - val_bbox_regression_loss: 0.9338 - val_probability_accuracy: 0.8810
# Epoch 35/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.3007 - probability_loss: 0.3230 - bbox_regression_loss: 0.9656 - probability_accuracy: 0.8524 - val_loss: 1.2014 - val_probability_loss: 0.2552 - val_bbox_regression_loss: 0.9340 - val_probability_accuracy: 0.8798
# Epoch 36/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2998 - probability_loss: 0.3224 - bbox_regression_loss: 0.9654 - probability_accuracy: 0.8524 - val_loss: 1.1999 - val_probability_loss: 0.2541 - val_bbox_regression_loss: 0.9336 - val_probability_accuracy: 0.8834
# Epoch 37/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2914 - probability_loss: 0.3159 - bbox_regression_loss: 0.9634 - probability_accuracy: 0.8575 - val_loss: 1.1977 - val_probability_loss: 0.2521 - val_bbox_regression_loss: 0.9335 - val_probability_accuracy: 0.8855
# Epoch 38/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2968 - probability_loss: 0.3218 - bbox_regression_loss: 0.9629 - probability_accuracy: 0.8584 - val_loss: 1.1950 - val_probability_loss: 0.2511 - val_bbox_regression_loss: 0.9317 - val_probability_accuracy: 0.8830
# Epoch 39/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2835 - probability_loss: 0.3114 - bbox_regression_loss: 0.9600 - probability_accuracy: 0.8600 - val_loss: 1.1927 - val_probability_loss: 0.2488 - val_bbox_regression_loss: 0.9317 - val_probability_accuracy: 0.8855
# Epoch 40/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2795 - probability_loss: 0.3063 - bbox_regression_loss: 0.9610 - probability_accuracy: 0.8650 - val_loss: 1.1903 - val_probability_loss: 0.2473 - val_bbox_regression_loss: 0.9309 - val_probability_accuracy: 0.8871
# Epoch 41/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2741 - probability_loss: 0.3045 - bbox_regression_loss: 0.9574 - probability_accuracy: 0.8623 - val_loss: 1.1893 - val_probability_loss: 0.2476 - val_bbox_regression_loss: 0.9296 - val_probability_accuracy: 0.8867
# Epoch 42/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2731 - probability_loss: 0.3029 - bbox_regression_loss: 0.9580 - probability_accuracy: 0.8650 - val_loss: 1.1867 - val_probability_loss: 0.2448 - val_bbox_regression_loss: 0.9298 - val_probability_accuracy: 0.8883
# Epoch 43/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2655 - probability_loss: 0.2970 - bbox_regression_loss: 0.9563 - probability_accuracy: 0.8685 - val_loss: 1.1838 - val_probability_loss: 0.2427 - val_bbox_regression_loss: 0.9289 - val_probability_accuracy: 0.8895
# Epoch 44/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2657 - probability_loss: 0.2970 - bbox_regression_loss: 0.9565 - probability_accuracy: 0.8675 - val_loss: 1.1822 - val_probability_loss: 0.2405 - val_bbox_regression_loss: 0.9295 - val_probability_accuracy: 0.8911
# Epoch 45/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2635 - probability_loss: 0.2955 - bbox_regression_loss: 0.9558 - probability_accuracy: 0.8675 - val_loss: 1.1799 - val_probability_loss: 0.2386 - val_bbox_regression_loss: 0.9292 - val_probability_accuracy: 0.8927
# Epoch 46/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2557 - probability_loss: 0.2895 - bbox_regression_loss: 0.9540 - probability_accuracy: 0.8761 - val_loss: 1.1786 - val_probability_loss: 0.2380 - val_bbox_regression_loss: 0.9284 - val_probability_accuracy: 0.8939
# Epoch 47/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2542 - probability_loss: 0.2888 - bbox_regression_loss: 0.9531 - probability_accuracy: 0.8762 - val_loss: 1.1772 - val_probability_loss: 0.2368 - val_bbox_regression_loss: 0.9281 - val_probability_accuracy: 0.8955
# Epoch 48/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2531 - probability_loss: 0.2886 - bbox_regression_loss: 0.9523 - probability_accuracy: 0.8748 - val_loss: 1.1741 - val_probability_loss: 0.2345 - val_bbox_regression_loss: 0.9274 - val_probability_accuracy: 0.8955
# Epoch 49/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2521 - probability_loss: 0.2876 - bbox_regression_loss: 0.9522 - probability_accuracy: 0.8726 - val_loss: 1.1729 - val_probability_loss: 0.2327 - val_bbox_regression_loss: 0.9280 - val_probability_accuracy: 0.8967
# Epoch 50/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2446 - probability_loss: 0.2821 - bbox_regression_loss: 0.9503 - probability_accuracy: 0.8777 - val_loss: 1.1709 - val_probability_loss: 0.2316 - val_bbox_regression_loss: 0.9271 - val_probability_accuracy: 0.8971
# Epoch 51/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2446 - probability_loss: 0.2831 - bbox_regression_loss: 0.9492 - probability_accuracy: 0.8784 - val_loss: 1.1691 - val_probability_loss: 0.2299 - val_bbox_regression_loss: 0.9270 - val_probability_accuracy: 0.8979
# Epoch 52/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2428 - probability_loss: 0.2820 - bbox_regression_loss: 0.9486 - probability_accuracy: 0.8778 - val_loss: 1.1678 - val_probability_loss: 0.2290 - val_bbox_regression_loss: 0.9265 - val_probability_accuracy: 0.8983
# Epoch 53/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2381 - probability_loss: 0.2754 - bbox_regression_loss: 0.9504 - probability_accuracy: 0.8825 - val_loss: 1.1660 - val_probability_loss: 0.2271 - val_bbox_regression_loss: 0.9266 - val_probability_accuracy: 0.9007
# Epoch 54/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2317 - probability_loss: 0.2729 - bbox_regression_loss: 0.9465 - probability_accuracy: 0.8809 - val_loss: 1.1648 - val_probability_loss: 0.2267 - val_bbox_regression_loss: 0.9259 - val_probability_accuracy: 0.8983
# Epoch 55/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2329 - probability_loss: 0.2734 - bbox_regression_loss: 0.9472 - probability_accuracy: 0.8816 - val_loss: 1.1617 - val_probability_loss: 0.2238 - val_bbox_regression_loss: 0.9256 - val_probability_accuracy: 0.9027
# Epoch 56/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2345 - probability_loss: 0.2743 - bbox_regression_loss: 0.9479 - probability_accuracy: 0.8799 - val_loss: 1.1592 - val_probability_loss: 0.2218 - val_bbox_regression_loss: 0.9251 - val_probability_accuracy: 0.9015
# Epoch 57/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2277 - probability_loss: 0.2679 - bbox_regression_loss: 0.9475 - probability_accuracy: 0.8866 - val_loss: 1.1586 - val_probability_loss: 0.2208 - val_bbox_regression_loss: 0.9255 - val_probability_accuracy: 0.9047
# Epoch 58/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2256 - probability_loss: 0.2670 - bbox_regression_loss: 0.9463 - probability_accuracy: 0.8859 - val_loss: 1.1574 - val_probability_loss: 0.2191 - val_bbox_regression_loss: 0.9260 - val_probability_accuracy: 0.9027
# Epoch 59/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2252 - probability_loss: 0.2669 - bbox_regression_loss: 0.9460 - probability_accuracy: 0.8867 - val_loss: 1.1550 - val_probability_loss: 0.2180 - val_bbox_regression_loss: 0.9247 - val_probability_accuracy: 0.9035
# Epoch 60/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2166 - probability_loss: 0.2586 - bbox_regression_loss: 0.9456 - probability_accuracy: 0.8922 - val_loss: 1.1524 - val_probability_loss: 0.2164 - val_bbox_regression_loss: 0.9237 - val_probability_accuracy: 0.9023
# Epoch 61/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2193 - probability_loss: 0.2622 - bbox_regression_loss: 0.9447 - probability_accuracy: 0.8904 - val_loss: 1.1513 - val_probability_loss: 0.2149 - val_bbox_regression_loss: 0.9241 - val_probability_accuracy: 0.9043
# Epoch 62/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2122 - probability_loss: 0.2549 - bbox_regression_loss: 0.9449 - probability_accuracy: 0.8930 - val_loss: 1.1491 - val_probability_loss: 0.2131 - val_bbox_regression_loss: 0.9236 - val_probability_accuracy: 0.9039
# Epoch 63/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2153 - probability_loss: 0.2581 - bbox_regression_loss: 0.9448 - probability_accuracy: 0.8918 - val_loss: 1.1476 - val_probability_loss: 0.2119 - val_bbox_regression_loss: 0.9234 - val_probability_accuracy: 0.9023
# Epoch 64/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2109 - probability_loss: 0.2548 - bbox_regression_loss: 0.9437 - probability_accuracy: 0.8929 - val_loss: 1.1467 - val_probability_loss: 0.2108 - val_bbox_regression_loss: 0.9235 - val_probability_accuracy: 0.9051
# Epoch 65/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2089 - probability_loss: 0.2539 - bbox_regression_loss: 0.9426 - probability_accuracy: 0.8949 - val_loss: 1.1450 - val_probability_loss: 0.2093 - val_bbox_regression_loss: 0.9233 - val_probability_accuracy: 0.9072
# Epoch 66/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2106 - probability_loss: 0.2559 - bbox_regression_loss: 0.9423 - probability_accuracy: 0.8954 - val_loss: 1.1441 - val_probability_loss: 0.2087 - val_bbox_regression_loss: 0.9230 - val_probability_accuracy: 0.9084
# Epoch 67/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2079 - probability_loss: 0.2532 - bbox_regression_loss: 0.9423 - probability_accuracy: 0.8943 - val_loss: 1.1427 - val_probability_loss: 0.2079 - val_bbox_regression_loss: 0.9224 - val_probability_accuracy: 0.9055
# Epoch 68/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.2005 - probability_loss: 0.2463 - bbox_regression_loss: 0.9418 - probability_accuracy: 0.8972 - val_loss: 1.1408 - val_probability_loss: 0.2066 - val_bbox_regression_loss: 0.9218 - val_probability_accuracy: 0.9064
# Epoch 69/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.1975 - probability_loss: 0.2443 - bbox_regression_loss: 0.9407 - probability_accuracy: 0.9028 - val_loss: 1.1388 - val_probability_loss: 0.2046 - val_bbox_regression_loss: 0.9218 - val_probability_accuracy: 0.9084
# Epoch 70/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.1949 - probability_loss: 0.2407 - bbox_regression_loss: 0.9419 - probability_accuracy: 0.8999 - val_loss: 1.1386 - val_probability_loss: 0.2047 - val_bbox_regression_loss: 0.9215 - val_probability_accuracy: 0.9072
# Epoch 71/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.1920 - probability_loss: 0.2382 - bbox_regression_loss: 0.9414 - probability_accuracy: 0.9031 - val_loss: 1.1362 - val_probability_loss: 0.2025 - val_bbox_regression_loss: 0.9213 - val_probability_accuracy: 0.9100
# Epoch 72/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.1893 - probability_loss: 0.2365 - bbox_regression_loss: 0.9404 - probability_accuracy: 0.9054 - val_loss: 1.1337 - val_probability_loss: 0.2005 - val_bbox_regression_loss: 0.9208 - val_probability_accuracy: 0.9120
# Epoch 73/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.1953 - probability_loss: 0.2436 - bbox_regression_loss: 0.9392 - probability_accuracy: 0.9017 - val_loss: 1.1331 - val_probability_loss: 0.1998 - val_bbox_regression_loss: 0.9208 - val_probability_accuracy: 0.9104
# Epoch 74/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.1936 - probability_loss: 0.2403 - bbox_regression_loss: 0.9408 - probability_accuracy: 0.9046 - val_loss: 1.1304 - val_probability_loss: 0.1976 - val_bbox_regression_loss: 0.9205 - val_probability_accuracy: 0.9116
# Epoch 75/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.1867 - probability_loss: 0.2355 - bbox_regression_loss: 0.9388 - probability_accuracy: 0.9040 - val_loss: 1.1301 - val_probability_loss: 0.1978 - val_bbox_regression_loss: 0.9199 - val_probability_accuracy: 0.9124
# Epoch 76/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.1882 - probability_loss: 0.2363 - bbox_regression_loss: 0.9395 - probability_accuracy: 0.9036 - val_loss: 1.1281 - val_probability_loss: 0.1965 - val_bbox_regression_loss: 0.9192 - val_probability_accuracy: 0.9128
# Epoch 77/500
# 622/622 [==============================] - 2s 3ms/step - loss: 1.1825 - probability_loss: 0.2318 - bbox_regression_loss: 0.9382 - probability_accuracy: 0.9044 - val_loss: 1.1260 - val_probability_loss: 0.1950 - val_bbox_regression_loss: 0.9185 - val_probability_accuracy: 0.9120
# Epoch 78/500
# 379/622 [=================>............] - ETA: 0s - loss: 1.1803 - probability_loss: 0.2268 - bbox_regression_loss: 0.9411 - probability_accuracy: 0.9108

# %% [markdown]
# # Test P-Net proposals

# %%
def __nms(boxes, s, threshold, method):
    """
        Non Maximum Suppression.

        Params:
            @param boxes: np array with bounding boxes.
            @param threshold:
            @param method: NMS method to apply. Available values ('Min', 'Union')
        
        Return:
            pick : An array of indices selected.
    """
    if boxes.size == 0:
        return np.empty((0, 3))

    x1 = boxes[:, 0]
    y1 = boxes[:, 1]
    x2 = boxes[:, 2] + x1
    y2 = boxes[:, 3] + y1

    area = (x2 - x1 + 1) * (y2 - y1 + 1)
    sorted_s = np.argsort(s)

    pick = np.zeros_like(s, dtype=np.int16)
    counter = 0
    while sorted_s.size > 0:
        i = sorted_s[-1]
        pick[counter] = i
        counter += 1
        idx = sorted_s[0:-1]

        xx1 = np.maximum(x1[i], x1[idx])
        yy1 = np.maximum(y1[i], y1[idx])
        xx2 = np.minimum(x2[i], x2[idx])
        yy2 = np.minimum(y2[i], y2[idx])

        w = np.maximum(0.0, xx2 - xx1 + 1)
        h = np.maximum(0.0, yy2 - yy1 + 1)

        inter = w * h

        if method == 'Min':
            o = inter / np.minimum(area[i], area[idx])
        else:
            o = inter / (area[i] + area[idx] - inter)

        sorted_s = sorted_s[np.where(o <= threshold)]

    pick = pick[0:counter]

    return pick

# %%
# raw_img = cv2.imread(os.path.join(train_dir, 'road155.png'))
# raw_img = cv2.imread(os.path.join(train_dir, 'road198.png'))
# raw_img = cv2.imread(os.path.join(train_dir, 'road202.png'))
raw_img = cv2.imread(os.path.join(train_dir, 'road215.png'))
raw_img = cv2.cvtColor(raw_img, cv2.COLOR_BGR2RGB)

def get_bboxes_pnet(raw_img, threshold=0.5, nms_threshold=0.5,
                    scale_factor=2.0, min_img_size = 48, padding = 0.15, visualize=False):
    '''
        
    '''
    H, W = raw_img.shape[:2]
    images = [raw_img]
    current_h, current_w = raw_img.shape[:2]
    
    ### 1. Get image pyramid ###
    while(current_h > min_img_size and current_w > min_img_size):
        current_h = int(current_h / scale_factor)
        current_w = int(current_w / scale_factor)

        if(current_w < min_img_size or current_h < min_img_size) : break

        image = cv2.resize(raw_img, (current_w, current_h))
        images.append(image)

    ### 2. Get bounding boxes from each image in the pyramid ###
    boxes = []
    conf_maps_viz = []
    for i, image in enumerate(images):
        if(i == 0): scale = 1
        else : scale = scale_factor ** i

        img = (image - 127.5) / 127.5
        height, width = image.shape[:2]

        predictions = pnet.predict(np.array([img]))
        features_shape = predictions[1][0].shape[:2]

        scale_w = width / features_shape[1]
        scale_h = height / features_shape[0]

        bboxes = predictions[1][0]
        raw_bboxes = bboxes
        confidence = predictions[0][0]

        ### Getting confidence map ###
        conf_map = confidence[:, :, 1]
        conf_map[conf_map > threshold] = 1.0
        conf_map[conf_map <= threshold] = 0
        conf_map = (conf_map * 255).astype(np.uint8)
        contours, hierarchy = cv2.findContours(conf_map, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
        
        conf_maps_viz.append(conf_map)
        
        for contour in contours:
            rect = cv2.boundingRect(contour)
            x, y, w, h = (rect * np.array([W/conf_map.shape[1],H/conf_map.shape[0],W/conf_map.shape[1],H/conf_map.shape[0] ])).astype(int)

            x -= min(int(padding * w), x)
            y -= min(int(padding * h), y)
            w += 2*int(padding * w)
            h += 2*int(padding * h)
            if(w * h < (W * H)/64): continue
            boxes.append([x,y,w,h])
    
    ### Performing nms ###
    final_boxes = []
    pick = __nms(np.array(boxes), np.ones((len(boxes))), nms_threshold, 'Min')
    for i in range(len(boxes)):
        final_boxes.append(boxes[i])
        
    crops = []
    if(visualize):
        fig, ax = plt.subplots(1, len(conf_maps_viz) + 1, figsize=(5*(len(conf_maps_viz) + 1), 5))
        for i in range(len(conf_maps_viz)):
            current_size = (H // (scale_factor ** i),W // (scale_factor**i))
            ax[i].imshow(conf_maps_viz[i])
            ax[i].set_title(f'Stage {i+1} {current_size}')
        
    raw_img_copy = raw_img.copy()
    for (x, y, w, h) in final_boxes:
        cv2.rectangle(raw_img_copy, (x,y), (x+w, y+h), (0,0,255),2)
        crops.append([(x,y,w,h), raw_img[y:y+h, x:x+w]])
            
    if(visualize):
        plt.imshow(raw_img_copy)
        plt.show()
        
    return final_boxes, crops
        
boxes, crops = get_bboxes_pnet(raw_img, visualize=True)

# %%
raw_img_copy = raw_img.copy()
for i in crops:
    crop = i[1]
    (x, y, w, h) = i[0]
    H, W = crop.shape[:2]
    img = cv2.resize(crop, (input_dim*2, input_dim*2))
    img = (img - 127.5) / 127.5
    
    prediction = rnet.predict(np.array([img]))
    confidence = prediction[0][0][0][0]
    
    label = np.argmax(confidence)
    confidence = confidence[np.argmax(confidence)]
    
    bbox = prediction[1][0][0][0]
    if(confidence < 0.9 or label == 0):continue
    
    x_,y_,w,h = (bbox * np.array([W, H, W, H])).astype('uint8')
    x+=x_
    y+=y_
    
    raw_img_copy = cv2.rectangle(raw_img_copy, (x, y), (x+w, y+h), (0,255,0), 2)
    raw_img_copy = cv2.putText(raw_img_copy, f'{confidence:.2f}', (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,255))
    
plt.imshow(raw_img_copy)
plt.show()
