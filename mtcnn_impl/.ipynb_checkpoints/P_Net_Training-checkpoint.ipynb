# %% [markdown]
# # Import libraries

# %%
import os
import cv2
import random
import numpy as np
import matplotlib.pyplot as plt

### Other dependencies ###
from PIL import Image
from sklearn.preprocessing import OneHotEncoder

### Tensorflow dependencies ###
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import MeanIoU
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError, BinaryCrossentropy

### Some constants ###
pnet_weights = 'weights/pnet.weights.hdf5'
# train_dir = "/home/minhhieu/Desktop/Hieu/datasets/GTSDB/TrainIJCNN2013/TrainIJCNN2013"
train_dir = "/home/minhhieu/Desktop/Hieu/datasets/RoadSignDetection/images"
test_dir = "/home/minhhieu/Desktop/Hieu/datasets/GTSDB/TestIJCNN2013/TestIJCNN2013Download"

# %% [markdown]
# # Load and explore dataset

# %%
def load_raw_dataset(dataset_dir, gt_file, delimiter=';'):
    '''
        This function will take in a dataset directory with ppm images (according to the DTSDB dataset)
        then it will return a list where each element is a list of 3 items. First item is the image, the
        second item is the bounding box and the last is the class ID.
        
        Params :
            @dataset_dir : Dataset directory.
            @gt_file : The file that consists of ground truth annotation in the format
            <img_pth>;<left>;<top>;<right>;<bottom>;<class_idx>.
            @delimiter : The separator of each item in each line of the ground truth file
            
        Returns :
            raw_dataset : list of elements [<cv2_img>, <gt_bbox>, <class_idx>]
    '''
    gt_abs_path = os.path.join(dataset_dir, gt_file)
    lines = open(gt_abs_path, 'r').readlines()
    
    images_to_gt = [[x.strip().split(delimiter)[0],   # Image path
                     x.strip().split(delimiter)[1:5], # Bbox regression ground truth
                     x.strip().split(delimiter)[5]]   # The class index
                    for x in lines]
    
    raw_dataset = [[cv2.imread(os.path.join(dataset_dir, x[0])),
                    np.array(x[1]).astype('int'),
                    int(x[2])]
                  for x in images_to_gt]
    
    print(f'[INFO] {len(raw_dataset)} samples loaded ... ')
    
    return raw_dataset
    
raw_dataset = load_raw_dataset(train_dir, 'gt.txt')

### Visualize sample data ###
img = raw_dataset[1][0].copy()
bbox = raw_dataset[1][1]
x1, y1, x2, y2 = bbox
img = cv2.rectangle(img, (x1, y1), (x2, y2), (0,255,0), 2)
plt.imshow(img)
plt.show()
# Out:
# [INFO] 1244 samples loaded ...

# %% [markdown]
# ### Generating negative samples (samples without traffic signs)

# %%
def generate_neg_samples(raw_dataset, crop_size=(48, 48)):
    '''
        This function will generate croppings of fixed size without any traffic sign
        and return those croppings with dummy bbox ground truth
        
        Params:
            @raw_dataset : The raw dataset formated similarly above
            @crop_size : The fixed cropping size
            
        Return:
            neg_samples : A list in format [<crop_img>,<dummy_bbox>,0]
    '''
    neg_samples = []
    for img, bbox, class_id in raw_dataset:
        height, width = img.shape[:2]
        x1, y1, x2, y2 = bbox
        range_x = ((0, max(x1 - crop_size[0], 0)), (min(x2 + crop_size[0], width), width))
        range_y = ((0, max(y1 - crop_size[1], 0)), (min(y2 + crop_size[1], height), height))
        
        ### Generate a random x,y coordinates ###
        x = random.choice([random.randint(range_x[0][0], range_x[0][1]), 
                           random.randint(range_x[1][0], range_x[1][1])])
        y = random.choice([random.randint(range_y[0][0], range_y[0][1]), 
                           random.randint(range_y[1][0], range_y[1][1])])
        
        # regenerate if cropping does not satisfy the size requirements
        while(width - x < crop_size[0] or height - y < crop_size[1]):
            x = random.choice([random.randint(range_x[0][0], range_x[0][1]), 
                           random.randint(range_x[1][0], range_x[1][1])])
            y = random.choice([random.randint(range_y[0][0], range_y[0][1]), 
                           random.randint(range_y[1][0], range_y[1][1])])
        
        crop = img[y:y+crop_size[1], x:x+crop_size[0]]
        neg_samples.append([crop, np.array([0,0,0,0]), 0])
        
    print(f'[INFO] {len(neg_samples)} negative samples generated ... ')
    return np.array(neg_samples)

neg_samples = generate_neg_samples(raw_dataset, crop_size=(48,48))
plt.imshow(neg_samples[1][0].copy())
plt.show()
# Out:
# [INFO] 1244 negative samples generated ...

# %% [markdown]
# ### Generate positive samples (samles with traffic signs)

# %%
def generate_pos_samples(raw_dataset, pad_range=(10, 100), img_size=48):
    '''
        This function will generate croppings with traffic signs
        and return those croppings with bbox ground truth
        
        Params:
            @raw_dataset : The raw dataset formated similarly above
            @pad_range : The pad range around the ground truth bounding box
            
        Return:
            pos_samples : A list in format [<crop_img>,<bbox>,1]
    '''
    pos_samples = []
    for img, bbox, class_id in raw_dataset:
        height, width = img.shape[:2]
        x1, y1, x2, y2 = bbox
        pad_x1 = min(x1, random.randint(pad_range[0], pad_range[1]))
        pad_x2 = min(width - x2, random.randint(pad_range[0], pad_range[1]))
        pad_y1 = min(y1, random.randint(pad_range[0], pad_range[1]))
        pad_y2 = min(height - y2, random.randint(pad_range[0], pad_range[1]))
        
        crop = img[y1 - pad_y1:y2 + pad_y2, x1 - pad_x1:x2 + pad_x2]
        h, w = crop.shape[:2]
        
        gt = np.array([pad_x1, pad_y1, pad_x1 + x2 - x1, pad_y1 + y2 - y1])
        gt[2] = gt[2] - gt[0] # Calculates width
        gt[3] = gt[3] - gt[1] # Calculates height
        gt = np.multiply(gt, np.array([1/w, 1/h, 1/w, 1/h])).astype('float32')
        
        crop = cv2.resize(crop, (img_size, img_size))
        pos_samples.append([crop, gt, 1])
        
    print(f'[INFO] {len(pos_samples)} positive samples generated ... ')
    return np.array(pos_samples)

pos_samples = generate_pos_samples(raw_dataset, pad_range=(5, 50), img_size=48)

img, gt, label = pos_samples[6]
img = img.copy()
h, w = img.shape[:2]
x1, y1, w, h = np.multiply(gt, np.array([w,h,w,h])).astype('int')

img = cv2.rectangle(img, (x1, y1), (x1+w, y1+h), 2)
plt.imshow(img)
plt.show()
# Out:
# [INFO] 1244 positive samples generated ...

# %% [markdown]
# ### Combine negative and positive samples to form training dataset

# %%
# Concatenate two groups and shuffle
train_dataset = np.concatenate([pos_samples, neg_samples])
np.random.shuffle(train_dataset)

train_images = np.array([x[0] for x in train_dataset])
train_bboxes = np.array([x[1] for x in train_dataset])
train_labels = OneHotEncoder().fit_transform(train_dataset[:,2].reshape(-1, 1)).toarray()

train_bboxes = train_bboxes.reshape(-1, 1, 1, 4)
train_labels = train_labels.reshape(-1, 1, 1, 2)

train_images = ((train_images - 127.5) / 127.5).astype('float32')
train_bboxes = train_bboxes.astype('float32')
train_labels = train_labels.astype('float32')

# %% [markdown]
# # Implement P-Net architecture

# %%
def build_pnet_model():
    inputs = Input(shape=(None, None, 3))
    p_layer = Conv2D(10, kernel_size=(3, 3), strides=(1, 1), padding="valid")(inputs)
    p_layer = PReLU(shared_axes=[1, 2])(p_layer)
    p_layer = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding="same")(p_layer)

    p_layer = Conv2D(10, kernel_size=(3, 3), strides=(1, 1), padding="valid")(p_layer)
    p_layer = PReLU(shared_axes=[1, 2])(p_layer)
    p_layer = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding="same")(p_layer)

    p_layer = Conv2D(10, kernel_size=(3, 3), strides=(1, 1), padding="valid")(p_layer)
    p_layer = PReLU(shared_axes=[1, 2])(p_layer)
    p_layer = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding="same")(p_layer)
    
    p_layer = Conv2D(16, kernel_size=(3, 3), strides=(1, 1), padding="valid")(p_layer)
    p_layer = PReLU(shared_axes=[1, 2])(p_layer)

    p_layer = Conv2D(32, kernel_size=(3, 3), strides=(1, 1), padding="valid")(p_layer)
    p_layer = PReLU(shared_axes=[1, 2])(p_layer)

    p_layer_out1 = Conv2D(2, kernel_size=(1, 1), strides=(1, 1))(p_layer)
    p_layer_out1 = Softmax(axis=3, name='probability')(p_layer_out1)

    p_layer_out2 = Conv2D(4, kernel_size=(1, 1), strides=(1, 1), activation='sigmoid', name='bbox_regression')(p_layer)

    p_net = Model(inputs, [p_layer_out1, p_layer_out2], name='P-Net')

    return p_net

pnet = build_pnet_model()
print(pnet.summary())
# print(pnet(tf.random.normal((1,48,48,3))))
# Out:
# Model: "P-Net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, None, None, 1 280         input_1[0][0]
# __________________________________________________________________________________________________
# p_re_lu (PReLU)                 (None, None, None, 1 10          conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, None, None, 1 0           p_re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 1 910         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# p_re_lu_1 (PReLU)               (None, None, None, 1 10          conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 1 0           p_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 1 910         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# p_re_lu_2 (PReLU)               (None, None, None, 1 10          conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, None, None, 1 0           p_re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 1 1456        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# p_re_lu_3 (PReLU)               (None, None, None, 1 16          conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 3 4640        p_re_lu_3[0][0]
# __________________________________________________________________________________________________
# p_re_lu_4 (PReLU)               (None, None, None, 3 32          conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 2 66          p_re_lu_4[0][0]
# __________________________________________________________________________________________________
# probability (Softmax)           (None, None, None, 2 0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# bbox_regression (Conv2D)        (None, None, None, 4 132         p_re_lu_4[0][0]
# ==================================================================================================
# Total params: 8,472
# Trainable params: 8,472
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# # Start training

# %%
losses = {
    'probability' : BinaryCrossentropy(),
    'bbox_regression' : MeanSquaredError(reduction=tf.keras.losses.Reduction.SUM)
}

y = {
    'probability' : train_labels,
    'bbox_regression' : train_bboxes
}

if(os.path.exists(pnet_weights)):
    pnet.load_weights(pnet_weights)
pnet.compile(optimizer=Adam(lr=0.00001, amsgrad=True),
            loss=losses,
            metrics={'probability':'accuracy','bbox_regression':MeanIoU(num_classes=2)})

# %%
epochs = 250
tensorboard = TensorBoard(log_dir="./logs")
checkpoint = ModelCheckpoint('weights/pnet.weights.hdf5', save_weights_only=True)
history = pnet.fit(train_images, y, epochs=epochs, batch_size=16, callbacks=[tensorboard, checkpoint])
# Out:
# Epoch 1/250
#   2/156 [..............................] - ETA: 4s - loss: 0.1707 - probability_loss: 0.0423 - bbox_regression_loss: 0.1285 - probability_accuracy: 0.9688 - bbox_regression_mean_io_u: 1.0000WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0032s vs `on_train_batch_end` time: 0.0607s). Check your callbacks.
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1532 - probability_loss: 0.0415 - bbox_regression_loss: 0.1117 - probability_accuracy: 0.9895 - bbox_regression_mean_io_u: 1.0000
# Epoch 2/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1524 - probability_loss: 0.0410 - bbox_regression_loss: 0.1114 - probability_accuracy: 0.9891 - bbox_regression_mean_io_u: 1.0000
# Epoch 3/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1520 - probability_loss: 0.0410 - bbox_regression_loss: 0.1110 - probability_accuracy: 0.9904 - bbox_regression_mean_io_u: 1.0000
# Epoch 4/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1523 - probability_loss: 0.0409 - bbox_regression_loss: 0.1114 - probability_accuracy: 0.9900 - bbox_regression_mean_io_u: 1.0000
# Epoch 5/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1546 - probability_loss: 0.0424 - bbox_regression_loss: 0.1122 - probability_accuracy: 0.9883 - bbox_regression_mean_io_u: 1.0000
# Epoch 6/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1507 - probability_loss: 0.0398 - bbox_regression_loss: 0.1109 - probability_accuracy: 0.9883 - bbox_regression_mean_io_u: 1.0000
# Epoch 7/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1522 - probability_loss: 0.0406 - bbox_regression_loss: 0.1116 - probability_accuracy: 0.9895 - bbox_regression_mean_io_u: 1.0000
# Epoch 8/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1514 - probability_loss: 0.0401 - bbox_regression_loss: 0.1113 - probability_accuracy: 0.9904 - bbox_regression_mean_io_u: 1.0000
# Epoch 9/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1514 - probability_loss: 0.0404 - bbox_regression_loss: 0.1109 - probability_accuracy: 0.9904 - bbox_regression_mean_io_u: 1.0000
# Epoch 10/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1511 - probability_loss: 0.0402 - bbox_regression_loss: 0.1109 - probability_accuracy: 0.9891 - bbox_regression_mean_io_u: 1.0000
# Epoch 11/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1516 - probability_loss: 0.0407 - bbox_regression_loss: 0.1109 - probability_accuracy: 0.9887 - bbox_regression_mean_io_u: 1.0000
# Epoch 12/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1534 - probability_loss: 0.0418 - bbox_regression_loss: 0.1116 - probability_accuracy: 0.9879 - bbox_regression_mean_io_u: 1.0000
# Epoch 13/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1505 - probability_loss: 0.0399 - bbox_regression_loss: 0.1106 - probability_accuracy: 0.9904 - bbox_regression_mean_io_u: 1.0000
# Epoch 14/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1518 - probability_loss: 0.0406 - bbox_regression_loss: 0.1111 - probability_accuracy: 0.9900 - bbox_regression_mean_io_u: 1.0000
# Epoch 15/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1507 - probability_loss: 0.0400 - bbox_regression_loss: 0.1107 - probability_accuracy: 0.9887 - bbox_regression_mean_io_u: 1.0000
# Epoch 16/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1518 - probability_loss: 0.0408 - bbox_regression_loss: 0.1110 - probability_accuracy: 0.9887 - bbox_regression_mean_io_u: 1.0000
# Epoch 17/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1506 - probability_loss: 0.0399 - bbox_regression_loss: 0.1107 - probability_accuracy: 0.9900 - bbox_regression_mean_io_u: 1.0000
# Epoch 18/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1514 - probability_loss: 0.0400 - bbox_regression_loss: 0.1114 - probability_accuracy: 0.9904 - bbox_regression_mean_io_u: 1.0000
# Epoch 19/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1504 - probability_loss: 0.0400 - bbox_regression_loss: 0.1104 - probability_accuracy: 0.9891 - bbox_regression_mean_io_u: 1.0000
# Epoch 20/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1507 - probability_loss: 0.0403 - bbox_regression_loss: 0.1104 - probability_accuracy: 0.9891 - bbox_regression_mean_io_u: 1.0000
# Epoch 21/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1511 - probability_loss: 0.0402 - bbox_regression_loss: 0.1109 - probability_accuracy: 0.9887 - bbox_regression_mean_io_u: 1.0000
# Epoch 22/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1521 - probability_loss: 0.0410 - bbox_regression_loss: 0.1112 - probability_accuracy: 0.9887 - bbox_regression_mean_io_u: 1.0000
# Epoch 23/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1511 - probability_loss: 0.0404 - bbox_regression_loss: 0.1108 - probability_accuracy: 0.9891 - bbox_regression_mean_io_u: 1.0000
# Epoch 24/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1509 - probability_loss: 0.0402 - bbox_regression_loss: 0.1108 - probability_accuracy: 0.9895 - bbox_regression_mean_io_u: 1.0000
# Epoch 25/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1500 - probability_loss: 0.0395 - bbox_regression_loss: 0.1105 - probability_accuracy: 0.9900 - bbox_regression_mean_io_u: 1.0000
# Epoch 26/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1501 - probability_loss: 0.0400 - bbox_regression_loss: 0.1102 - probability_accuracy: 0.9895 - bbox_regression_mean_io_u: 1.0000
# Epoch 27/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1504 - probability_loss: 0.0397 - bbox_regression_loss: 0.1107 - probability_accuracy: 0.9908 - bbox_regression_mean_io_u: 1.0000
# Epoch 28/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1498 - probability_loss: 0.0394 - bbox_regression_loss: 0.1103 - probability_accuracy: 0.9904 - bbox_regression_mean_io_u: 1.0000
# Epoch 29/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1512 - probability_loss: 0.0403 - bbox_regression_loss: 0.1108 - probability_accuracy: 0.9895 - bbox_regression_mean_io_u: 1.0000
# Epoch 30/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1491 - probability_loss: 0.0391 - bbox_regression_loss: 0.1099 - probability_accuracy: 0.9904 - bbox_regression_mean_io_u: 1.0000
# Epoch 31/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1501 - probability_loss: 0.0397 - bbox_regression_loss: 0.1104 - probability_accuracy: 0.9912 - bbox_regression_mean_io_u: 1.0000
# Epoch 32/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1507 - probability_loss: 0.0401 - bbox_regression_loss: 0.1105 - probability_accuracy: 0.9900 - bbox_regression_mean_io_u: 1.0000
# Epoch 33/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1501 - probability_loss: 0.0396 - bbox_regression_loss: 0.1105 - probability_accuracy: 0.9895 - bbox_regression_mean_io_u: 1.0000
# Epoch 34/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1488 - probability_loss: 0.0389 - bbox_regression_loss: 0.1099 - probability_accuracy: 0.9916 - bbox_regression_mean_io_u: 1.0000
# Epoch 35/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1495 - probability_loss: 0.0396 - bbox_regression_loss: 0.1099 - probability_accuracy: 0.9904 - bbox_regression_mean_io_u: 1.0000
# Epoch 36/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1485 - probability_loss: 0.0387 - bbox_regression_loss: 0.1098 - probability_accuracy: 0.9904 - bbox_regression_mean_io_u: 1.0000
# Epoch 37/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1485 - probability_loss: 0.0389 - bbox_regression_loss: 0.1096 - probability_accuracy: 0.9908 - bbox_regression_mean_io_u: 1.0000
# Epoch 38/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1494 - probability_loss: 0.0392 - bbox_regression_loss: 0.1103 - probability_accuracy: 0.9891 - bbox_regression_mean_io_u: 1.0000
# Epoch 39/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1492 - probability_loss: 0.0392 - bbox_regression_loss: 0.1099 - probability_accuracy: 0.9916 - bbox_regression_mean_io_u: 1.0000
# Epoch 40/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1505 - probability_loss: 0.0399 - bbox_regression_loss: 0.1106 - probability_accuracy: 0.9883 - bbox_regression_mean_io_u: 1.0000
# Epoch 41/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1493 - probability_loss: 0.0390 - bbox_regression_loss: 0.1102 - probability_accuracy: 0.9895 - bbox_regression_mean_io_u: 1.0000
# Epoch 42/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1485 - probability_loss: 0.0387 - bbox_regression_loss: 0.1098 - probability_accuracy: 0.9904 - bbox_regression_mean_io_u: 1.0000
# Epoch 43/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1476 - probability_loss: 0.0384 - bbox_regression_loss: 0.1092 - probability_accuracy: 0.9904 - bbox_regression_mean_io_u: 1.0000
# Epoch 44/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1490 - probability_loss: 0.0391 - bbox_regression_loss: 0.1099 - probability_accuracy: 0.9900 - bbox_regression_mean_io_u: 1.0000
# Epoch 45/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1493 - probability_loss: 0.0390 - bbox_regression_loss: 0.1103 - probability_accuracy: 0.9900 - bbox_regression_mean_io_u: 1.0000
# Epoch 46/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1510 - probability_loss: 0.0403 - bbox_regression_loss: 0.1107 - probability_accuracy: 0.9879 - bbox_regression_mean_io_u: 1.0000
# Epoch 47/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1491 - probability_loss: 0.0391 - bbox_regression_loss: 0.1100 - probability_accuracy: 0.9900 - bbox_regression_mean_io_u: 1.0000
# Epoch 48/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1492 - probability_loss: 0.0392 - bbox_regression_loss: 0.1100 - probability_accuracy: 0.9908 - bbox_regression_mean_io_u: 1.0000
# Epoch 49/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1491 - probability_loss: 0.0391 - bbox_regression_loss: 0.1101 - probability_accuracy: 0.9908 - bbox_regression_mean_io_u: 1.0000
# Epoch 50/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1476 - probability_loss: 0.0384 - bbox_regression_loss: 0.1092 - probability_accuracy: 0.9916 - bbox_regression_mean_io_u: 1.0000
# Epoch 51/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1485 - probability_loss: 0.0389 - bbox_regression_loss: 0.1096 - probability_accuracy: 0.9895 - bbox_regression_mean_io_u: 1.0000
# Epoch 52/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1488 - probability_loss: 0.0393 - bbox_regression_loss: 0.1096 - probability_accuracy: 0.9900 - bbox_regression_mean_io_u: 1.0000
# Epoch 53/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1475 - probability_loss: 0.0381 - bbox_regression_loss: 0.1094 - probability_accuracy: 0.9908 - bbox_regression_mean_io_u: 1.0000
# Epoch 54/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1477 - probability_loss: 0.0383 - bbox_regression_loss: 0.1094 - probability_accuracy: 0.9908 - bbox_regression_mean_io_u: 1.0000
# Epoch 55/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1479 - probability_loss: 0.0387 - bbox_regression_loss: 0.1092 - probability_accuracy: 0.9908 - bbox_regression_mean_io_u: 1.0000
# Epoch 56/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1473 - probability_loss: 0.0380 - bbox_regression_loss: 0.1093 - probability_accuracy: 0.9908 - bbox_regression_mean_io_u: 1.0000
# Epoch 57/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1486 - probability_loss: 0.0385 - bbox_regression_loss: 0.1101 - probability_accuracy: 0.9904 - bbox_regression_mean_io_u: 1.0000
# Epoch 58/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1469 - probability_loss: 0.0379 - bbox_regression_loss: 0.1090 - probability_accuracy: 0.9912 - bbox_regression_mean_io_u: 1.0000
# Epoch 59/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1476 - probability_loss: 0.0386 - bbox_regression_loss: 0.1090 - probability_accuracy: 0.9912 - bbox_regression_mean_io_u: 1.0000
# Epoch 60/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1477 - probability_loss: 0.0383 - bbox_regression_loss: 0.1094 - probability_accuracy: 0.9912 - bbox_regression_mean_io_u: 1.0000
# Epoch 61/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1471 - probability_loss: 0.0378 - bbox_regression_loss: 0.1093 - probability_accuracy: 0.9891 - bbox_regression_mean_io_u: 1.0000
# Epoch 62/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1478 - probability_loss: 0.0389 - bbox_regression_loss: 0.1089 - probability_accuracy: 0.9900 - bbox_regression_mean_io_u: 1.0000
# Epoch 63/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1499 - probability_loss: 0.0401 - bbox_regression_loss: 0.1098 - probability_accuracy: 0.9891 - bbox_regression_mean_io_u: 1.0000
# Epoch 64/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1469 - probability_loss: 0.0380 - bbox_regression_loss: 0.1089 - probability_accuracy: 0.9904 - bbox_regression_mean_io_u: 1.0000
# Epoch 65/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1469 - probability_loss: 0.0375 - bbox_regression_loss: 0.1094 - probability_accuracy: 0.9924 - bbox_regression_mean_io_u: 1.0000
# Epoch 66/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1480 - probability_loss: 0.0387 - bbox_regression_loss: 0.1093 - probability_accuracy: 0.9908 - bbox_regression_mean_io_u: 1.0000
# Epoch 67/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1472 - probability_loss: 0.0384 - bbox_regression_loss: 0.1087 - probability_accuracy: 0.9908 - bbox_regression_mean_io_u: 1.0000
# Epoch 68/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1475 - probability_loss: 0.0382 - bbox_regression_loss: 0.1093 - probability_accuracy: 0.9920 - bbox_regression_mean_io_u: 1.0000
# Epoch 69/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1473 - probability_loss: 0.0382 - bbox_regression_loss: 0.1091 - probability_accuracy: 0.9908 - bbox_regression_mean_io_u: 1.0000
# Epoch 70/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1464 - probability_loss: 0.0379 - bbox_regression_loss: 0.1085 - probability_accuracy: 0.9908 - bbox_regression_mean_io_u: 1.0000
# Epoch 71/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1477 - probability_loss: 0.0377 - bbox_regression_loss: 0.1099 - probability_accuracy: 0.9904 - bbox_regression_mean_io_u: 1.0000
# Epoch 72/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1468 - probability_loss: 0.0380 - bbox_regression_loss: 0.1088 - probability_accuracy: 0.9900 - bbox_regression_mean_io_u: 1.0000
# Epoch 73/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1450 - probability_loss: 0.0368 - bbox_regression_loss: 0.1082 - probability_accuracy: 0.9908 - bbox_regression_mean_io_u: 1.0000
# Epoch 74/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1453 - probability_loss: 0.0369 - bbox_regression_loss: 0.1083 - probability_accuracy: 0.9912 - bbox_regression_mean_io_u: 1.0000
# Epoch 75/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1454 - probability_loss: 0.0371 - bbox_regression_loss: 0.1082 - probability_accuracy: 0.9916 - bbox_regression_mean_io_u: 1.0000
# Epoch 76/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1466 - probability_loss: 0.0377 - bbox_regression_loss: 0.1090 - probability_accuracy: 0.9912 - bbox_regression_mean_io_u: 1.0000
# Epoch 77/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1457 - probability_loss: 0.0373 - bbox_regression_loss: 0.1084 - probability_accuracy: 0.9904 - bbox_regression_mean_io_u: 1.0000
# Epoch 78/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1453 - probability_loss: 0.0372 - bbox_regression_loss: 0.1081 - probability_accuracy: 0.9908 - bbox_regression_mean_io_u: 1.0000
# Epoch 79/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1465 - probability_loss: 0.0380 - bbox_regression_loss: 0.1085 - probability_accuracy: 0.9908 - bbox_regression_mean_io_u: 1.0000
# Epoch 80/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1462 - probability_loss: 0.0377 - bbox_regression_loss: 0.1085 - probability_accuracy: 0.9916 - bbox_regression_mean_io_u: 1.0000
# Epoch 81/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1455 - probability_loss: 0.0374 - bbox_regression_loss: 0.1081 - probability_accuracy: 0.9916 - bbox_regression_mean_io_u: 1.0000
# Epoch 82/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1462 - probability_loss: 0.0377 - bbox_regression_loss: 0.1086 - probability_accuracy: 0.9908 - bbox_regression_mean_io_u: 1.0000
# Epoch 83/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1460 - probability_loss: 0.0376 - bbox_regression_loss: 0.1084 - probability_accuracy: 0.9912 - bbox_regression_mean_io_u: 1.0000
# Epoch 84/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1458 - probability_loss: 0.0374 - bbox_regression_loss: 0.1084 - probability_accuracy: 0.9912 - bbox_regression_mean_io_u: 1.0000
# Epoch 85/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1459 - probability_loss: 0.0378 - bbox_regression_loss: 0.1082 - probability_accuracy: 0.9891 - bbox_regression_mean_io_u: 1.0000
# Epoch 86/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1466 - probability_loss: 0.0377 - bbox_regression_loss: 0.1089 - probability_accuracy: 0.9912 - bbox_regression_mean_io_u: 1.0000
# Epoch 87/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1463 - probability_loss: 0.0376 - bbox_regression_loss: 0.1087 - probability_accuracy: 0.9904 - bbox_regression_mean_io_u: 1.0000
# Epoch 88/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1464 - probability_loss: 0.0376 - bbox_regression_loss: 0.1088 - probability_accuracy: 0.9912 - bbox_regression_mean_io_u: 1.0000
# Epoch 89/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1451 - probability_loss: 0.0370 - bbox_regression_loss: 0.1081 - probability_accuracy: 0.9920 - bbox_regression_mean_io_u: 1.0000
# Epoch 90/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1449 - probability_loss: 0.0367 - bbox_regression_loss: 0.1082 - probability_accuracy: 0.9916 - bbox_regression_mean_io_u: 1.0000
# Epoch 91/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1444 - probability_loss: 0.0368 - bbox_regression_loss: 0.1076 - probability_accuracy: 0.9916 - bbox_regression_mean_io_u: 1.0000
# Epoch 92/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1451 - probability_loss: 0.0368 - bbox_regression_loss: 0.1083 - probability_accuracy: 0.9904 - bbox_regression_mean_io_u: 1.0000
# Epoch 93/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1454 - probability_loss: 0.0375 - bbox_regression_loss: 0.1079 - probability_accuracy: 0.9908 - bbox_regression_mean_io_u: 1.0000
# Epoch 94/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1454 - probability_loss: 0.0374 - bbox_regression_loss: 0.1080 - probability_accuracy: 0.9916 - bbox_regression_mean_io_u: 1.0000
# Epoch 95/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1444 - probability_loss: 0.0369 - bbox_regression_loss: 0.1074 - probability_accuracy: 0.9908 - bbox_regression_mean_io_u: 1.0000
# Epoch 96/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1447 - probability_loss: 0.0370 - bbox_regression_loss: 0.1077 - probability_accuracy: 0.9912 - bbox_regression_mean_io_u: 1.0000
# Epoch 97/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1439 - probability_loss: 0.0364 - bbox_regression_loss: 0.1076 - probability_accuracy: 0.9900 - bbox_regression_mean_io_u: 1.0000
# Epoch 98/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1457 - probability_loss: 0.0374 - bbox_regression_loss: 0.1083 - probability_accuracy: 0.9916 - bbox_regression_mean_io_u: 1.0000
# Epoch 99/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1453 - probability_loss: 0.0369 - bbox_regression_loss: 0.1084 - probability_accuracy: 0.9916 - bbox_regression_mean_io_u: 1.0000
# Epoch 100/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1446 - probability_loss: 0.0367 - bbox_regression_loss: 0.1079 - probability_accuracy: 0.9900 - bbox_regression_mean_io_u: 1.0000
# Epoch 101/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1433 - probability_loss: 0.0360 - bbox_regression_loss: 0.1073 - probability_accuracy: 0.9924 - bbox_regression_mean_io_u: 1.0000
# Epoch 102/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1433 - probability_loss: 0.0361 - bbox_regression_loss: 0.1072 - probability_accuracy: 0.9920 - bbox_regression_mean_io_u: 1.0000
# Epoch 103/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1445 - probability_loss: 0.0365 - bbox_regression_loss: 0.1080 - probability_accuracy: 0.9900 - bbox_regression_mean_io_u: 1.0000
# Epoch 104/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1460 - probability_loss: 0.0375 - bbox_regression_loss: 0.1086 - probability_accuracy: 0.9924 - bbox_regression_mean_io_u: 1.0000
# Epoch 105/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1445 - probability_loss: 0.0368 - bbox_regression_loss: 0.1077 - probability_accuracy: 0.9916 - bbox_regression_mean_io_u: 1.0000
# Epoch 106/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1441 - probability_loss: 0.0364 - bbox_regression_loss: 0.1077 - probability_accuracy: 0.9920 - bbox_regression_mean_io_u: 1.0000
# Epoch 107/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1436 - probability_loss: 0.0362 - bbox_regression_loss: 0.1073 - probability_accuracy: 0.9924 - bbox_regression_mean_io_u: 1.0000
# Epoch 108/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1449 - probability_loss: 0.0366 - bbox_regression_loss: 0.1083 - probability_accuracy: 0.9920 - bbox_regression_mean_io_u: 1.0000
# Epoch 109/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1443 - probability_loss: 0.0363 - bbox_regression_loss: 0.1079 - probability_accuracy: 0.9912 - bbox_regression_mean_io_u: 1.0000
# Epoch 110/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1434 - probability_loss: 0.0361 - bbox_regression_loss: 0.1073 - probability_accuracy: 0.9920 - bbox_regression_mean_io_u: 1.0000
# Epoch 111/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1440 - probability_loss: 0.0369 - bbox_regression_loss: 0.1071 - probability_accuracy: 0.9895 - bbox_regression_mean_io_u: 1.0000
# Epoch 112/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1443 - probability_loss: 0.0366 - bbox_regression_loss: 0.1077 - probability_accuracy: 0.9908 - bbox_regression_mean_io_u: 1.0000
# Epoch 113/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1426 - probability_loss: 0.0354 - bbox_regression_loss: 0.1072 - probability_accuracy: 0.9920 - bbox_regression_mean_io_u: 1.0000
# Epoch 114/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1434 - probability_loss: 0.0361 - bbox_regression_loss: 0.1073 - probability_accuracy: 0.9900 - bbox_regression_mean_io_u: 1.0000
# Epoch 115/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1438 - probability_loss: 0.0360 - bbox_regression_loss: 0.1078 - probability_accuracy: 0.9920 - bbox_regression_mean_io_u: 1.0000
# Epoch 116/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1420 - probability_loss: 0.0354 - bbox_regression_loss: 0.1066 - probability_accuracy: 0.9916 - bbox_regression_mean_io_u: 1.0000
# Epoch 117/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1430 - probability_loss: 0.0359 - bbox_regression_loss: 0.1072 - probability_accuracy: 0.9904 - bbox_regression_mean_io_u: 1.0000
# Epoch 118/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1456 - probability_loss: 0.0376 - bbox_regression_loss: 0.1079 - probability_accuracy: 0.9908 - bbox_regression_mean_io_u: 1.0000
# Epoch 119/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1428 - probability_loss: 0.0359 - bbox_regression_loss: 0.1069 - probability_accuracy: 0.9920 - bbox_regression_mean_io_u: 1.0000
# Epoch 120/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1433 - probability_loss: 0.0359 - bbox_regression_loss: 0.1074 - probability_accuracy: 0.9920 - bbox_regression_mean_io_u: 1.0000
# Epoch 121/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1436 - probability_loss: 0.0360 - bbox_regression_loss: 0.1077 - probability_accuracy: 0.9924 - bbox_regression_mean_io_u: 1.0000
# Epoch 122/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1423 - probability_loss: 0.0352 - bbox_regression_loss: 0.1072 - probability_accuracy: 0.9928 - bbox_regression_mean_io_u: 1.0000
# Epoch 123/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1434 - probability_loss: 0.0363 - bbox_regression_loss: 0.1071 - probability_accuracy: 0.9920 - bbox_regression_mean_io_u: 1.0000
# Epoch 124/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1418 - probability_loss: 0.0351 - bbox_regression_loss: 0.1067 - probability_accuracy: 0.9920 - bbox_regression_mean_io_u: 1.0000
# Epoch 125/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1420 - probability_loss: 0.0357 - bbox_regression_loss: 0.1063 - probability_accuracy: 0.9920 - bbox_regression_mean_io_u: 1.0000
# Epoch 126/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1419 - probability_loss: 0.0352 - bbox_regression_loss: 0.1067 - probability_accuracy: 0.9916 - bbox_regression_mean_io_u: 1.0000
# Epoch 127/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1413 - probability_loss: 0.0350 - bbox_regression_loss: 0.1063 - probability_accuracy: 0.9928 - bbox_regression_mean_io_u: 1.0000
# Epoch 128/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1422 - probability_loss: 0.0358 - bbox_regression_loss: 0.1065 - probability_accuracy: 0.9916 - bbox_regression_mean_io_u: 1.0000
# Epoch 129/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1429 - probability_loss: 0.0356 - bbox_regression_loss: 0.1073 - probability_accuracy: 0.9924 - bbox_regression_mean_io_u: 1.0000
# Epoch 130/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1425 - probability_loss: 0.0357 - bbox_regression_loss: 0.1068 - probability_accuracy: 0.9920 - bbox_regression_mean_io_u: 1.0000
# Epoch 131/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1445 - probability_loss: 0.0370 - bbox_regression_loss: 0.1075 - probability_accuracy: 0.9904 - bbox_regression_mean_io_u: 1.0000
# Epoch 132/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1428 - probability_loss: 0.0357 - bbox_regression_loss: 0.1071 - probability_accuracy: 0.9920 - bbox_regression_mean_io_u: 1.0000
# Epoch 133/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1422 - probability_loss: 0.0354 - bbox_regression_loss: 0.1069 - probability_accuracy: 0.9924 - bbox_regression_mean_io_u: 1.0000
# Epoch 134/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1416 - probability_loss: 0.0352 - bbox_regression_loss: 0.1063 - probability_accuracy: 0.9928 - bbox_regression_mean_io_u: 1.0000
# Epoch 135/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1404 - probability_loss: 0.0346 - bbox_regression_loss: 0.1058 - probability_accuracy: 0.9928 - bbox_regression_mean_io_u: 1.0000
# Epoch 136/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1424 - probability_loss: 0.0358 - bbox_regression_loss: 0.1066 - probability_accuracy: 0.9924 - bbox_regression_mean_io_u: 1.0000
# Epoch 137/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1412 - probability_loss: 0.0350 - bbox_regression_loss: 0.1063 - probability_accuracy: 0.9928 - bbox_regression_mean_io_u: 1.0000
# Epoch 138/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1412 - probability_loss: 0.0347 - bbox_regression_loss: 0.1064 - probability_accuracy: 0.9920 - bbox_regression_mean_io_u: 1.0000
# Epoch 139/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1420 - probability_loss: 0.0352 - bbox_regression_loss: 0.1068 - probability_accuracy: 0.9912 - bbox_regression_mean_io_u: 1.0000
# Epoch 140/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1412 - probability_loss: 0.0350 - bbox_regression_loss: 0.1063 - probability_accuracy: 0.9924 - bbox_regression_mean_io_u: 1.0000
# Epoch 141/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1411 - probability_loss: 0.0346 - bbox_regression_loss: 0.1065 - probability_accuracy: 0.9920 - bbox_regression_mean_io_u: 1.0000
# Epoch 142/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1414 - probability_loss: 0.0352 - bbox_regression_loss: 0.1062 - probability_accuracy: 0.9924 - bbox_regression_mean_io_u: 1.0000
# Epoch 143/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1425 - probability_loss: 0.0358 - bbox_regression_loss: 0.1066 - probability_accuracy: 0.9924 - bbox_regression_mean_io_u: 1.0000
# Epoch 144/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1418 - probability_loss: 0.0353 - bbox_regression_loss: 0.1065 - probability_accuracy: 0.9920 - bbox_regression_mean_io_u: 1.0000
# Epoch 145/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1403 - probability_loss: 0.0344 - bbox_regression_loss: 0.1058 - probability_accuracy: 0.9928 - bbox_regression_mean_io_u: 1.0000
# Epoch 146/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1404 - probability_loss: 0.0344 - bbox_regression_loss: 0.1060 - probability_accuracy: 0.9936 - bbox_regression_mean_io_u: 1.0000
# Epoch 147/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1422 - probability_loss: 0.0356 - bbox_regression_loss: 0.1066 - probability_accuracy: 0.9908 - bbox_regression_mean_io_u: 1.0000
# Epoch 148/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1395 - probability_loss: 0.0338 - bbox_regression_loss: 0.1057 - probability_accuracy: 0.9928 - bbox_regression_mean_io_u: 1.0000
# Epoch 149/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1407 - probability_loss: 0.0346 - bbox_regression_loss: 0.1060 - probability_accuracy: 0.9928 - bbox_regression_mean_io_u: 1.0000
# Epoch 150/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1401 - probability_loss: 0.0341 - bbox_regression_loss: 0.1060 - probability_accuracy: 0.9932 - bbox_regression_mean_io_u: 1.0000
# Epoch 151/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1399 - probability_loss: 0.0341 - bbox_regression_loss: 0.1058 - probability_accuracy: 0.9932 - bbox_regression_mean_io_u: 1.0000
# Epoch 152/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1397 - probability_loss: 0.0340 - bbox_regression_loss: 0.1057 - probability_accuracy: 0.9932 - bbox_regression_mean_io_u: 1.0000
# Epoch 153/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1409 - probability_loss: 0.0346 - bbox_regression_loss: 0.1062 - probability_accuracy: 0.9920 - bbox_regression_mean_io_u: 1.0000
# Epoch 154/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1401 - probability_loss: 0.0342 - bbox_regression_loss: 0.1059 - probability_accuracy: 0.9924 - bbox_regression_mean_io_u: 1.0000
# Epoch 155/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1420 - probability_loss: 0.0351 - bbox_regression_loss: 0.1069 - probability_accuracy: 0.9932 - bbox_regression_mean_io_u: 1.0000
# Epoch 156/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1407 - probability_loss: 0.0348 - bbox_regression_loss: 0.1059 - probability_accuracy: 0.9920 - bbox_regression_mean_io_u: 1.0000
# Epoch 157/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1403 - probability_loss: 0.0344 - bbox_regression_loss: 0.1059 - probability_accuracy: 0.9920 - bbox_regression_mean_io_u: 1.0000
# Epoch 158/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1389 - probability_loss: 0.0334 - bbox_regression_loss: 0.1055 - probability_accuracy: 0.9920 - bbox_regression_mean_io_u: 1.0000
# Epoch 159/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1408 - probability_loss: 0.0346 - bbox_regression_loss: 0.1062 - probability_accuracy: 0.9920 - bbox_regression_mean_io_u: 1.0000
# Epoch 160/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1394 - probability_loss: 0.0340 - bbox_regression_loss: 0.1054 - probability_accuracy: 0.9920 - bbox_regression_mean_io_u: 1.0000
# Epoch 161/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1425 - probability_loss: 0.0354 - bbox_regression_loss: 0.1071 - probability_accuracy: 0.9920 - bbox_regression_mean_io_u: 1.0000
# Epoch 162/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1405 - probability_loss: 0.0348 - bbox_regression_loss: 0.1056 - probability_accuracy: 0.9924 - bbox_regression_mean_io_u: 1.0000
# Epoch 163/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1395 - probability_loss: 0.0339 - bbox_regression_loss: 0.1056 - probability_accuracy: 0.9920 - bbox_regression_mean_io_u: 1.0000
# Epoch 164/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1396 - probability_loss: 0.0342 - bbox_regression_loss: 0.1053 - probability_accuracy: 0.9924 - bbox_regression_mean_io_u: 1.0000
# Epoch 165/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1411 - probability_loss: 0.0348 - bbox_regression_loss: 0.1062 - probability_accuracy: 0.9932 - bbox_regression_mean_io_u: 1.0000
# Epoch 166/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1395 - probability_loss: 0.0340 - bbox_regression_loss: 0.1055 - probability_accuracy: 0.9932 - bbox_regression_mean_io_u: 1.0000
# Epoch 167/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1418 - probability_loss: 0.0354 - bbox_regression_loss: 0.1064 - probability_accuracy: 0.9924 - bbox_regression_mean_io_u: 1.0000
# Epoch 168/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1400 - probability_loss: 0.0343 - bbox_regression_loss: 0.1057 - probability_accuracy: 0.9920 - bbox_regression_mean_io_u: 1.0000
# Epoch 169/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1399 - probability_loss: 0.0340 - bbox_regression_loss: 0.1058 - probability_accuracy: 0.9936 - bbox_regression_mean_io_u: 1.0000
# Epoch 170/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1392 - probability_loss: 0.0340 - bbox_regression_loss: 0.1051 - probability_accuracy: 0.9916 - bbox_regression_mean_io_u: 1.0000
# Epoch 171/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1389 - probability_loss: 0.0337 - bbox_regression_loss: 0.1052 - probability_accuracy: 0.9928 - bbox_regression_mean_io_u: 1.0000
# Epoch 172/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1400 - probability_loss: 0.0343 - bbox_regression_loss: 0.1057 - probability_accuracy: 0.9936 - bbox_regression_mean_io_u: 1.0000
# Epoch 173/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1387 - probability_loss: 0.0339 - bbox_regression_loss: 0.1048 - probability_accuracy: 0.9924 - bbox_regression_mean_io_u: 1.0000
# Epoch 174/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1396 - probability_loss: 0.0342 - bbox_regression_loss: 0.1054 - probability_accuracy: 0.9928 - bbox_regression_mean_io_u: 1.0000
# Epoch 175/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1391 - probability_loss: 0.0339 - bbox_regression_loss: 0.1052 - probability_accuracy: 0.9924 - bbox_regression_mean_io_u: 1.0000
# Epoch 176/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1390 - probability_loss: 0.0339 - bbox_regression_loss: 0.1050 - probability_accuracy: 0.9932 - bbox_regression_mean_io_u: 1.0000
# Epoch 177/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1387 - probability_loss: 0.0338 - bbox_regression_loss: 0.1049 - probability_accuracy: 0.9936 - bbox_regression_mean_io_u: 1.0000
# Epoch 178/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1386 - probability_loss: 0.0333 - bbox_regression_loss: 0.1054 - probability_accuracy: 0.9924 - bbox_regression_mean_io_u: 1.0000
# Epoch 179/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1383 - probability_loss: 0.0333 - bbox_regression_loss: 0.1050 - probability_accuracy: 0.9916 - bbox_regression_mean_io_u: 1.0000
# Epoch 180/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1385 - probability_loss: 0.0336 - bbox_regression_loss: 0.1050 - probability_accuracy: 0.9944 - bbox_regression_mean_io_u: 1.0000
# Epoch 181/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1377 - probability_loss: 0.0333 - bbox_regression_loss: 0.1044 - probability_accuracy: 0.9916 - bbox_regression_mean_io_u: 1.0000
# Epoch 182/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1389 - probability_loss: 0.0339 - bbox_regression_loss: 0.1050 - probability_accuracy: 0.9924 - bbox_regression_mean_io_u: 1.0000
# Epoch 183/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1379 - probability_loss: 0.0334 - bbox_regression_loss: 0.1045 - probability_accuracy: 0.9928 - bbox_regression_mean_io_u: 1.0000
# Epoch 184/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1380 - probability_loss: 0.0331 - bbox_regression_loss: 0.1049 - probability_accuracy: 0.9932 - bbox_regression_mean_io_u: 1.0000
# Epoch 185/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1379 - probability_loss: 0.0331 - bbox_regression_loss: 0.1048 - probability_accuracy: 0.9928 - bbox_regression_mean_io_u: 1.0000
# Epoch 186/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1379 - probability_loss: 0.0332 - bbox_regression_loss: 0.1047 - probability_accuracy: 0.9936 - bbox_regression_mean_io_u: 1.0000
# Epoch 187/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1378 - probability_loss: 0.0330 - bbox_regression_loss: 0.1048 - probability_accuracy: 0.9932 - bbox_regression_mean_io_u: 1.0000
# Epoch 188/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1379 - probability_loss: 0.0332 - bbox_regression_loss: 0.1047 - probability_accuracy: 0.9932 - bbox_regression_mean_io_u: 1.0000
# Epoch 189/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1377 - probability_loss: 0.0331 - bbox_regression_loss: 0.1047 - probability_accuracy: 0.9940 - bbox_regression_mean_io_u: 1.0000
# Epoch 190/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1378 - probability_loss: 0.0332 - bbox_regression_loss: 0.1046 - probability_accuracy: 0.9928 - bbox_regression_mean_io_u: 1.0000
# Epoch 191/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1376 - probability_loss: 0.0332 - bbox_regression_loss: 0.1044 - probability_accuracy: 0.9932 - bbox_regression_mean_io_u: 1.0000
# Epoch 192/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1376 - probability_loss: 0.0329 - bbox_regression_loss: 0.1047 - probability_accuracy: 0.9928 - bbox_regression_mean_io_u: 1.0000
# Epoch 193/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1397 - probability_loss: 0.0342 - bbox_regression_loss: 0.1054 - probability_accuracy: 0.9908 - bbox_regression_mean_io_u: 1.0000
# Epoch 194/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1380 - probability_loss: 0.0331 - bbox_regression_loss: 0.1049 - probability_accuracy: 0.9912 - bbox_regression_mean_io_u: 1.0000
# Epoch 195/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1365 - probability_loss: 0.0324 - bbox_regression_loss: 0.1041 - probability_accuracy: 0.9932 - bbox_regression_mean_io_u: 1.0000
# Epoch 196/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1388 - probability_loss: 0.0337 - bbox_regression_loss: 0.1050 - probability_accuracy: 0.9924 - bbox_regression_mean_io_u: 1.0000
# Epoch 197/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1384 - probability_loss: 0.0339 - bbox_regression_loss: 0.1044 - probability_accuracy: 0.9924 - bbox_regression_mean_io_u: 1.0000
# Epoch 198/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1373 - probability_loss: 0.0330 - bbox_regression_loss: 0.1043 - probability_accuracy: 0.9924 - bbox_regression_mean_io_u: 1.0000
# Epoch 199/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1382 - probability_loss: 0.0335 - bbox_regression_loss: 0.1047 - probability_accuracy: 0.9920 - bbox_regression_mean_io_u: 1.0000
# Epoch 200/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1367 - probability_loss: 0.0326 - bbox_regression_loss: 0.1041 - probability_accuracy: 0.9932 - bbox_regression_mean_io_u: 1.0000
# Epoch 201/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1372 - probability_loss: 0.0331 - bbox_regression_loss: 0.1042 - probability_accuracy: 0.9932 - bbox_regression_mean_io_u: 1.0000
# Epoch 202/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1367 - probability_loss: 0.0325 - bbox_regression_loss: 0.1043 - probability_accuracy: 0.9936 - bbox_regression_mean_io_u: 1.0000
# Epoch 203/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1380 - probability_loss: 0.0331 - bbox_regression_loss: 0.1048 - probability_accuracy: 0.9920 - bbox_regression_mean_io_u: 1.0000
# Epoch 204/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1370 - probability_loss: 0.0327 - bbox_regression_loss: 0.1043 - probability_accuracy: 0.9928 - bbox_regression_mean_io_u: 1.0000
# Epoch 205/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1370 - probability_loss: 0.0325 - bbox_regression_loss: 0.1045 - probability_accuracy: 0.9928 - bbox_regression_mean_io_u: 1.0000
# Epoch 206/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1366 - probability_loss: 0.0324 - bbox_regression_loss: 0.1042 - probability_accuracy: 0.9944 - bbox_regression_mean_io_u: 1.0000
# Epoch 207/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1375 - probability_loss: 0.0330 - bbox_regression_loss: 0.1044 - probability_accuracy: 0.9928 - bbox_regression_mean_io_u: 1.0000
# Epoch 208/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1358 - probability_loss: 0.0323 - bbox_regression_loss: 0.1035 - probability_accuracy: 0.9944 - bbox_regression_mean_io_u: 1.0000
# Epoch 209/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1361 - probability_loss: 0.0321 - bbox_regression_loss: 0.1040 - probability_accuracy: 0.9932 - bbox_regression_mean_io_u: 1.0000
# Epoch 210/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1364 - probability_loss: 0.0325 - bbox_regression_loss: 0.1039 - probability_accuracy: 0.9936 - bbox_regression_mean_io_u: 1.0000
# Epoch 211/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1357 - probability_loss: 0.0318 - bbox_regression_loss: 0.1039 - probability_accuracy: 0.9940 - bbox_regression_mean_io_u: 1.0000
# Epoch 212/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1368 - probability_loss: 0.0326 - bbox_regression_loss: 0.1043 - probability_accuracy: 0.9936 - bbox_regression_mean_io_u: 1.0000
# Epoch 213/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1358 - probability_loss: 0.0322 - bbox_regression_loss: 0.1036 - probability_accuracy: 0.9932 - bbox_regression_mean_io_u: 1.0000
# Epoch 214/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1377 - probability_loss: 0.0332 - bbox_regression_loss: 0.1045 - probability_accuracy: 0.9928 - bbox_regression_mean_io_u: 1.0000
# Epoch 215/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1362 - probability_loss: 0.0323 - bbox_regression_loss: 0.1039 - probability_accuracy: 0.9924 - bbox_regression_mean_io_u: 1.0000
# Epoch 216/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1366 - probability_loss: 0.0327 - bbox_regression_loss: 0.1039 - probability_accuracy: 0.9936 - bbox_regression_mean_io_u: 1.0000
# Epoch 217/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1347 - probability_loss: 0.0312 - bbox_regression_loss: 0.1035 - probability_accuracy: 0.9928 - bbox_regression_mean_io_u: 1.0000
# Epoch 218/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1361 - probability_loss: 0.0320 - bbox_regression_loss: 0.1041 - probability_accuracy: 0.9940 - bbox_regression_mean_io_u: 1.0000
# Epoch 219/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1361 - probability_loss: 0.0323 - bbox_regression_loss: 0.1038 - probability_accuracy: 0.9936 - bbox_regression_mean_io_u: 1.0000
# Epoch 220/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1352 - probability_loss: 0.0317 - bbox_regression_loss: 0.1035 - probability_accuracy: 0.9944 - bbox_regression_mean_io_u: 1.0000
# Epoch 221/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1359 - probability_loss: 0.0319 - bbox_regression_loss: 0.1040 - probability_accuracy: 0.9928 - bbox_regression_mean_io_u: 1.0000
# Epoch 222/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1356 - probability_loss: 0.0319 - bbox_regression_loss: 0.1037 - probability_accuracy: 0.9936 - bbox_regression_mean_io_u: 1.0000
# Epoch 223/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1362 - probability_loss: 0.0326 - bbox_regression_loss: 0.1036 - probability_accuracy: 0.9928 - bbox_regression_mean_io_u: 1.0000
# Epoch 224/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1352 - probability_loss: 0.0317 - bbox_regression_loss: 0.1035 - probability_accuracy: 0.9940 - bbox_regression_mean_io_u: 1.0000
# Epoch 225/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1361 - probability_loss: 0.0322 - bbox_regression_loss: 0.1039 - probability_accuracy: 0.9936 - bbox_regression_mean_io_u: 1.0000
# Epoch 226/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1348 - probability_loss: 0.0316 - bbox_regression_loss: 0.1032 - probability_accuracy: 0.9940 - bbox_regression_mean_io_u: 1.0000
# Epoch 227/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1354 - probability_loss: 0.0320 - bbox_regression_loss: 0.1034 - probability_accuracy: 0.9940 - bbox_regression_mean_io_u: 1.0000
# Epoch 228/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1349 - probability_loss: 0.0317 - bbox_regression_loss: 0.1032 - probability_accuracy: 0.9928 - bbox_regression_mean_io_u: 1.0000
# Epoch 229/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1364 - probability_loss: 0.0320 - bbox_regression_loss: 0.1043 - probability_accuracy: 0.9924 - bbox_regression_mean_io_u: 1.0000
# Epoch 230/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1356 - probability_loss: 0.0320 - bbox_regression_loss: 0.1035 - probability_accuracy: 0.9944 - bbox_regression_mean_io_u: 1.0000
# Epoch 231/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1363 - probability_loss: 0.0330 - bbox_regression_loss: 0.1032 - probability_accuracy: 0.9924 - bbox_regression_mean_io_u: 1.0000
# Epoch 232/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1352 - probability_loss: 0.0318 - bbox_regression_loss: 0.1034 - probability_accuracy: 0.9936 - bbox_regression_mean_io_u: 1.0000
# Epoch 233/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1352 - probability_loss: 0.0316 - bbox_regression_loss: 0.1036 - probability_accuracy: 0.9936 - bbox_regression_mean_io_u: 1.0000
# Epoch 234/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1353 - probability_loss: 0.0315 - bbox_regression_loss: 0.1038 - probability_accuracy: 0.9944 - bbox_regression_mean_io_u: 1.0000
# Epoch 235/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1358 - probability_loss: 0.0319 - bbox_regression_loss: 0.1039 - probability_accuracy: 0.9936 - bbox_regression_mean_io_u: 1.0000
# Epoch 236/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1338 - probability_loss: 0.0310 - bbox_regression_loss: 0.1028 - probability_accuracy: 0.9936 - bbox_regression_mean_io_u: 1.0000
# Epoch 237/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1344 - probability_loss: 0.0316 - bbox_regression_loss: 0.1027 - probability_accuracy: 0.9932 - bbox_regression_mean_io_u: 1.0000
# Epoch 238/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1347 - probability_loss: 0.0315 - bbox_regression_loss: 0.1031 - probability_accuracy: 0.9940 - bbox_regression_mean_io_u: 1.0000
# Epoch 239/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1357 - probability_loss: 0.0319 - bbox_regression_loss: 0.1037 - probability_accuracy: 0.9936 - bbox_regression_mean_io_u: 1.0000
# Epoch 240/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1335 - probability_loss: 0.0307 - bbox_regression_loss: 0.1027 - probability_accuracy: 0.9940 - bbox_regression_mean_io_u: 1.0000
# Epoch 241/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1362 - probability_loss: 0.0323 - bbox_regression_loss: 0.1039 - probability_accuracy: 0.9920 - bbox_regression_mean_io_u: 1.0000
# Epoch 242/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1354 - probability_loss: 0.0318 - bbox_regression_loss: 0.1036 - probability_accuracy: 0.9940 - bbox_regression_mean_io_u: 1.0000
# Epoch 243/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1352 - probability_loss: 0.0321 - bbox_regression_loss: 0.1031 - probability_accuracy: 0.9948 - bbox_regression_mean_io_u: 1.0000
# Epoch 244/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1332 - probability_loss: 0.0306 - bbox_regression_loss: 0.1026 - probability_accuracy: 0.9952 - bbox_regression_mean_io_u: 1.0000
# Epoch 245/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1339 - probability_loss: 0.0310 - bbox_regression_loss: 0.1029 - probability_accuracy: 0.9936 - bbox_regression_mean_io_u: 1.0000
# Epoch 246/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1340 - probability_loss: 0.0312 - bbox_regression_loss: 0.1028 - probability_accuracy: 0.9936 - bbox_regression_mean_io_u: 1.0000
# Epoch 247/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1330 - probability_loss: 0.0306 - bbox_regression_loss: 0.1024 - probability_accuracy: 0.9940 - bbox_regression_mean_io_u: 1.0000
# Epoch 248/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1353 - probability_loss: 0.0319 - bbox_regression_loss: 0.1034 - probability_accuracy: 0.9916 - bbox_regression_mean_io_u: 1.0000
# Epoch 249/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1340 - probability_loss: 0.0312 - bbox_regression_loss: 0.1028 - probability_accuracy: 0.9948 - bbox_regression_mean_io_u: 1.0000
# Epoch 250/250
# 156/156 [==============================] - 0s 3ms/step - loss: 0.1351 - probability_loss: 0.0316 - bbox_regression_loss: 0.1034 - probability_accuracy: 0.9936 - bbox_regression_mean_io_u: 1.0000

# %% [markdown]
# # Test P-Net proposals

# %%
def __nms(boxes, s, threshold, method):
    """
        Non Maximum Suppression.

        Params:
            @param boxes: np array with bounding boxes.
            @param threshold:
            @param method: NMS method to apply. Available values ('Min', 'Union')
        
        Return:
            pick : An array of indices selected.
    """
    if boxes.size == 0:
        return np.empty((0, 3))

    x1 = boxes[:, 0]
    y1 = boxes[:, 1]
    x2 = boxes[:, 2] + x1
    y2 = boxes[:, 3] + y1

    area = (x2 - x1 + 1) * (y2 - y1 + 1)
    sorted_s = np.argsort(s)

    pick = np.zeros_like(s, dtype=np.int16)
    counter = 0
    while sorted_s.size > 0:
        i = sorted_s[-1]
        pick[counter] = i
        counter += 1
        idx = sorted_s[0:-1]

        xx1 = np.maximum(x1[i], x1[idx])
        yy1 = np.maximum(y1[i], y1[idx])
        xx2 = np.minimum(x2[i], x2[idx])
        yy2 = np.minimum(y2[i], y2[idx])

        w = np.maximum(0.0, xx2 - xx1 + 1)
        h = np.maximum(0.0, yy2 - yy1 + 1)

        inter = w * h

        if method == 'Min':
            o = inter / np.minimum(area[i], area[idx])
        else:
            o = inter / (area[i] + area[idx] - inter)
            print(o)

        sorted_s = sorted_s[np.where(o <= threshold)]

    pick = pick[0:counter]

    return pick

# %%
threshold = 0.8
nms_threshold = 0.1
raw_img = cv2.imread(os.path.join(train_dir, 'road195.png'))
img = (raw_img - 127.5) / 127.5
height, width = img.shape[:2]
#raw_img = cv2.resize(raw_img, (width//6,height//6))

bboxes = pnet.predict(np.array([img]))[1][0]
confidence = pnet.predict(np.array([img]))[0][0]

bboxes = bboxes.reshape(bboxes.shape[0] * bboxes.shape[1], 4)
confidence = confidence.reshape(confidence.shape[0] * confidence.shape[1], 2)
confidence = confidence[:,1].astype('float')

candidate_windows = bboxes[confidence > threshold]
confidence = confidence[confidence > threshold]

boxes = []
for window in candidate_windows:
    x1, y1, w, h = np.multiply(window, np.array([width, height, width, height])).astype('int')
    boxes.append([x1, y1, w, h])   

pick = __nms(np.array(boxes), confidence, nms_threshold, 'Min')
for i in pick:
    x,y,w,h = boxes[i]
    cv2.rectangle(raw_img, (x,y), (x+w, y+h), (0,255,0),2)

plt.imshow(raw_img)
plt.show()
