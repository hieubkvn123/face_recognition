# %% [markdown]
# # Import libraries

# %%
import os
import cv2
import random
import numpy as np
import matplotlib.pyplot as plt

### Other dependencies ###
from PIL import Image
from sklearn.preprocessing import OneHotEncoder

### Tensorflow dependencies ###
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import MeanIoU
from tensorflow.keras.losses import MeanSquaredError, BinaryCrossentropy

### Some constants ###
train_dir = "/home/minhhieu/Desktop/Hieu/datasets/GTSDB/TrainIJCNN2013/TrainIJCNN2013"
test_dir = "/home/minhhieu/Desktop/Hieu/datasets/GTSDB/TestIJCNN2013/TestIJCNN2013Download"

# %% [markdown]
# # Load and explore dataset

# %%
def load_raw_dataset(dataset_dir, gt_file, delimiter=';'):
    '''
        This function will take in a dataset directory with ppm images (according to the DTSDB dataset)
        then it will return a list where each element is a list of 3 items. First item is the image, the
        second item is the bounding box and the last is the class ID.
        
        Params :
            @dataset_dir : Dataset directory.
            @gt_file : The file that consists of ground truth annotation in the format
            <img_pth>;<left>;<top>;<right>;<bottom>;<class_idx>.
            @delimiter : The separator of each item in each line of the ground truth file
            
        Returns :
            raw_dataset : list of elements [<cv2_img>, <gt_bbox>, <class_idx>]
    '''
    gt_abs_path = os.path.join(dataset_dir, gt_file)
    lines = open(gt_abs_path, 'r').readlines()
    
    images_to_gt = [[x.strip().split(delimiter)[0],   # Image path
                     x.strip().split(delimiter)[1:5], # Bbox regression ground truth
                     x.strip().split(delimiter)[5]]   # The class index
                    for x in lines]
    
    raw_dataset = [[cv2.imread(os.path.join(dataset_dir, x[0])),
                    np.array(x[1]).astype('int'),
                    int(x[2])]
                  for x in images_to_gt]
    
    print(f'[INFO] {len(raw_dataset)} samples loaded ... ')
    
    return raw_dataset
    
raw_dataset = load_raw_dataset(train_dir, 'gt.txt')

### Visualize sample data ###
img = raw_dataset[1][0].copy()
bbox = raw_dataset[1][1]
x1, y1, x2, y2 = bbox
img = cv2.rectangle(img, (x1, y1), (x2, y2), (0,255,0), 2)
plt.imshow(img)
plt.show()
# Out:
# [INFO] 852 samples loaded ...

# %% [markdown]
# ### Generating negative samples (samples without traffic signs)

# %%
def generate_neg_samples(raw_dataset, crop_size=(48, 48)):
    '''
        This function will generate croppings of fixed size without any traffic sign
        and return those croppings with dummy bbox ground truth
        
        Params:
            @raw_dataset : The raw dataset formated similarly above
            @crop_size : The fixed cropping size
            
        Return:
            neg_samples : A list in format [<crop_img>,<dummy_bbox>,0]
    '''
    neg_samples = []
    for img, bbox, class_id in raw_dataset:
        height, width = img.shape[:2]
        x1, y1, x2, y2 = bbox
        range_x = ((0, max(x1 - crop_size[0], 0)), (min(x2 + crop_size[0], width), width))
        range_y = ((0, max(y1 - crop_size[1], 0)), (min(y2 + crop_size[1], height), height))
        
        ### Generate a random x,y coordinates ###
        x = random.choice([random.randint(range_x[0][0], range_x[0][1]), 
                           random.randint(range_x[1][0], range_x[1][1])])
        y = random.choice([random.randint(range_y[0][0], range_y[0][1]), 
                           random.randint(range_y[1][0], range_y[1][1])])
        
        # regenerate if cropping does not satisfy the size requirements
        while(width - x < crop_size[0] or height - y < crop_size[1]):
            x = random.choice([random.randint(range_x[0][0], range_x[0][1]), 
                           random.randint(range_x[1][0], range_x[1][1])])
            y = random.choice([random.randint(range_y[0][0], range_y[0][1]), 
                           random.randint(range_y[1][0], range_y[1][1])])
        
        crop = img[y:y+crop_size[1], x:x+crop_size[0]]
        neg_samples.append([crop, np.array([0,0,0,0]), 0])
        
    print(f'[INFO] {len(neg_samples)} negative samples generated ... ')
    return np.array(neg_samples)

neg_samples = generate_neg_samples(raw_dataset, crop_size=(48,48))
plt.imshow(neg_samples[1][0].copy())
plt.show()
# Out:
# [INFO] 852 negative samples generated ...

# %% [markdown]
# ### Generate positive samples (samles with traffic signs)

# %%
def generate_pos_samples(raw_dataset, pad_range=(10, 100), img_size=48):
    '''
        This function will generate croppings with traffic signs
        and return those croppings with bbox ground truth
        
        Params:
            @raw_dataset : The raw dataset formated similarly above
            @pad_range : The pad range around the ground truth bounding box
            
        Return:
            pos_samples : A list in format [<crop_img>,<bbox>,1]
    '''
    pos_samples = []
    for img, bbox, class_id in raw_dataset:
        height, width = img.shape[:2]
        x1, y1, x2, y2 = bbox
        pad_x1 = min(x1, random.randint(pad_range[0], pad_range[1]))
        pad_x2 = min(width - x2, random.randint(pad_range[0], pad_range[1]))
        pad_y1 = min(y1, random.randint(pad_range[0], pad_range[1]))
        pad_y2 = min(height - y2, random.randint(pad_range[0], pad_range[1]))
        
        crop = img[y1 - pad_y1:y2 + pad_y2, x1 - pad_x1:x2 + pad_x2]
        h, w = crop.shape[:2]
        
        gt = np.array([pad_x1, pad_y1, pad_x1 + x2 - x1, pad_y1 + y2 - y1])
        gt[2] = gt[2] - gt[0] # Calculates width
        gt[3] = gt[3] - gt[1] # Calculates height
        gt = np.multiply(gt, np.array([1/w, 1/h, 1/w, 1/h])).astype('float32')
        
        crop = cv2.resize(crop, (img_size, img_size))
        pos_samples.append([crop, gt, 1])
        
    print(f'[INFO] {len(pos_samples)} positive samples generated ... ')
    return np.array(pos_samples)

pos_samples = generate_pos_samples(raw_dataset, pad_range=(5, 50), img_size=48)

img, gt, label = pos_samples[6]
img = img.copy()
h, w = img.shape[:2]
x1, y1, w, h = np.multiply(gt, np.array([w,h,w,h])).astype('int')

img = cv2.rectangle(img, (x1, y1), (x1+w, y1+h), 2)
plt.imshow(img)
plt.show()
# Out:
# [INFO] 852 positive samples generated ...

# %% [markdown]
# ### Combine negative and positive samples to form training dataset

# %%
# Concatenate two groups and shuffle
train_dataset = np.concatenate([pos_samples, neg_samples])
np.random.shuffle(train_dataset)

train_images = np.array([x[0] for x in train_dataset])
train_bboxes = np.array([x[1] for x in train_dataset])
train_labels = OneHotEncoder().fit_transform(train_dataset[:,2].reshape(-1, 1)).toarray()

train_bboxes = train_bboxes.reshape(-1, 1, 1, 4)
train_labels = train_labels.reshape(-1, 1, 1, 2)

train_images = ((train_images - 127.5) / 127.5).astype('float32')
train_bboxes = train_bboxes.astype('float32')
train_labels = train_labels.astype('float32')

# %% [markdown]
# # Implement P-Net architecture

# %%
def build_pnet_model():
    inputs = Input(shape=(None, None, 3))
    p_layer = Conv2D(10, kernel_size=(3, 3), strides=(1, 1), padding="valid")(inputs)
    p_layer = PReLU(shared_axes=[1, 2])(p_layer)
    p_layer = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding="same")(p_layer)

    p_layer = Conv2D(10, kernel_size=(3, 3), strides=(1, 1), padding="valid")(p_layer)
    p_layer = PReLU(shared_axes=[1, 2])(p_layer)
    p_layer = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding="same")(p_layer)

    p_layer = Conv2D(10, kernel_size=(3, 3), strides=(1, 1), padding="valid")(p_layer)
    p_layer = PReLU(shared_axes=[1, 2])(p_layer)
    p_layer = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding="same")(p_layer)
    
    p_layer = Conv2D(16, kernel_size=(3, 3), strides=(1, 1), padding="valid")(p_layer)
    p_layer = PReLU(shared_axes=[1, 2])(p_layer)

    p_layer = Conv2D(32, kernel_size=(3, 3), strides=(1, 1), padding="valid")(p_layer)
    p_layer = PReLU(shared_axes=[1, 2])(p_layer)

    p_layer_out1 = Conv2D(2, kernel_size=(1, 1), strides=(1, 1))(p_layer)
    p_layer_out1 = Softmax(axis=3, name='probability')(p_layer_out1)

    p_layer_out2 = Conv2D(4, kernel_size=(1, 1), strides=(1, 1), activation='sigmoid', name='bbox_regression')(p_layer)

    p_net = Model(inputs, [p_layer_out1, p_layer_out2], name='P-Net')

    return p_net

pnet = build_pnet_model()
print(pnet.summary())
# print(pnet(tf.random.normal((1,48,48,3))))
# Out:
# Model: "P-Net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, None, None, 1 280         input_4[0][0]
# __________________________________________________________________________________________________
# p_re_lu_13 (PReLU)              (None, None, None, 1 10          conv2d_16[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, None, None, 1 0           p_re_lu_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, None, None, 1 910         max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# p_re_lu_14 (PReLU)              (None, None, None, 1 10          conv2d_17[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, None, None, 1 0           p_re_lu_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 1 910         max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# p_re_lu_15 (PReLU)              (None, None, None, 1 10          conv2d_18[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, None, None, 1 0           p_re_lu_15[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, None, None, 1 1456        max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# p_re_lu_16 (PReLU)              (None, None, None, 1 16          conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, None, None, 3 4640        p_re_lu_16[0][0]
# __________________________________________________________________________________________________
# p_re_lu_17 (PReLU)              (None, None, None, 3 32          conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, None, None, 2 66          p_re_lu_17[0][0]
# __________________________________________________________________________________________________
# probability (Softmax)           (None, None, None, 2 0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# bbox_regression (Conv2D)        (None, None, None, 4 132         p_re_lu_17[0][0]
# ==================================================================================================
# Total params: 8,472
# Trainable params: 8,472
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# # Start training

# %%
losses = {
    'probability' : BinaryCrossentropy(),
    'bbox_regression' : MeanSquaredError(reduction=tf.keras.losses.Reduction.SUM)
}

y = {
    'probability' : train_labels,
    'bbox_regression' : train_bboxes
}

print(train_labels.shape, train_bboxes.shape)
pnet.compile(optimizer=Adam(lr=0.00001, amsgrad=True),
            loss=losses,
            metrics={'probability':'accuracy'})
# Out:
# (1704, 1, 1, 2) (1704, 1, 1, 4)

# %%
history = pnet.fit(train_images, y, epochs=350, batch_size=16)
# Out:
# Epoch 1/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.
350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4486 - probability_loss: 0.2072 - bbox_regression_loss: 0.2414 - probability_accuracy: 0.9155
# Epoch 108/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4484 - probability_loss: 0.2067 - bbox_regression_loss: 0.2417 - probability_accuracy: 0.9155
# Epoch 109/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4479 - probability_loss: 0.2066 - bbox_regression_loss: 0.2412 - probability_accuracy: 0.9155
# Epoch 110/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4485 - probability_loss: 0.2071 - bbox_regression_loss: 0.2414 - probability_accuracy: 0.9143
# Epoch 111/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4481 - probability_loss: 0.2065 - bbox_regression_loss: 0.2417 - probability_accuracy: 0.9149
# Epoch 112/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4468 - probability_loss: 0.2059 - bbox_regression_loss: 0.2409 - probability_accuracy: 0.9143
# Epoch 113/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4472 - probability_loss: 0.2065 - bbox_regression_loss: 0.2407 - probability_accuracy: 0.9155
# Epoch 114/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4456 - probability_loss: 0.2052 - bbox_regression_loss: 0.2404 - probability_accuracy: 0.9143
# Epoch 115/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4458 - probability_loss: 0.2060 - bbox_regression_loss: 0.2398 - probability_accuracy: 0.9149
# Epoch 116/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4464 - probability_loss: 0.2060 - bbox_regression_loss: 0.2404 - probability_accuracy: 0.9143
# Epoch 117/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4463 - probability_loss: 0.2056 - bbox_regression_loss: 0.2407 - probability_accuracy: 0.9167
# Epoch 118/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4455 - probability_loss: 0.2051 - bbox_regression_loss: 0.2404 - probability_accuracy: 0.9155
# Epoch 119/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4455 - probability_loss: 0.2053 - bbox_regression_loss: 0.2402 - probability_accuracy: 0.9167
# Epoch 120/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4471 - probability_loss: 0.2059 - bbox_regression_loss: 0.2412 - probability_accuracy: 0.9131
# Epoch 121/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4446 - probability_loss: 0.2047 - bbox_regression_loss: 0.2399 - probability_accuracy: 0.9173
# Epoch 122/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4426 - probability_loss: 0.2039 - bbox_regression_loss: 0.2387 - probability_accuracy: 0.9137
# Epoch 123/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4430 - probability_loss: 0.2038 - bbox_regression_loss: 0.2392 - probability_accuracy: 0.9143
# Epoch 124/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4435 - probability_loss: 0.2042 - bbox_regression_loss: 0.2394 - probability_accuracy: 0.9155
# Epoch 125/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4432 - probability_loss: 0.2040 - bbox_regression_loss: 0.2393 - probability_accuracy: 0.9167
# Epoch 126/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4445 - probability_loss: 0.2043 - bbox_regression_loss: 0.2402 - probability_accuracy: 0.9149
# Epoch 127/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4432 - probability_loss: 0.2040 - bbox_regression_loss: 0.2392 - probability_accuracy: 0.9178
# Epoch 128/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4438 - probability_loss: 0.2041 - bbox_regression_loss: 0.2397 - probability_accuracy: 0.9155
# Epoch 129/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4432 - probability_loss: 0.2038 - bbox_regression_loss: 0.2394 - probability_accuracy: 0.9131
# Epoch 130/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4412 - probability_loss: 0.2027 - bbox_regression_loss: 0.2384 - probability_accuracy: 0.9173
# Epoch 131/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4411 - probability_loss: 0.2027 - bbox_regression_loss: 0.2384 - probability_accuracy: 0.9149
# Epoch 132/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4406 - probability_loss: 0.2027 - bbox_regression_loss: 0.2379 - probability_accuracy: 0.9149
# Epoch 133/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4401 - probability_loss: 0.2025 - bbox_regression_loss: 0.2376 - probability_accuracy: 0.9155
# Epoch 134/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4396 - probability_loss: 0.2022 - bbox_regression_loss: 0.2373 - probability_accuracy: 0.9161
# Epoch 135/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4407 - probability_loss: 0.2028 - bbox_regression_loss: 0.2378 - probability_accuracy: 0.9167
# Epoch 136/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4412 - probability_loss: 0.2027 - bbox_regression_loss: 0.2384 - probability_accuracy: 0.9161
# Epoch 137/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4407 - probability_loss: 0.2023 - bbox_regression_loss: 0.2384 - probability_accuracy: 0.9167
# Epoch 138/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4382 - probability_loss: 0.2014 - bbox_regression_loss: 0.2368 - probability_accuracy: 0.9190
# Epoch 139/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4386 - probability_loss: 0.2017 - bbox_regression_loss: 0.2368 - probability_accuracy: 0.9167
# Epoch 140/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4379 - probability_loss: 0.2012 - bbox_regression_loss: 0.2367 - probability_accuracy: 0.9155
# Epoch 141/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4386 - probability_loss: 0.2014 - bbox_regression_loss: 0.2372 - probability_accuracy: 0.9161
# Epoch 142/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4377 - probability_loss: 0.2011 - bbox_regression_loss: 0.2366 - probability_accuracy: 0.9161
# Epoch 143/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4391 - probability_loss: 0.2020 - bbox_regression_loss: 0.2371 - probability_accuracy: 0.9184
# Epoch 144/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4407 - probability_loss: 0.2028 - bbox_regression_loss: 0.2379 - probability_accuracy: 0.9155
# Epoch 145/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4376 - probability_loss: 0.2009 - bbox_regression_loss: 0.2367 - probability_accuracy: 0.9190
# Epoch 146/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4364 - probability_loss: 0.2000 - bbox_regression_loss: 0.2364 - probability_accuracy: 0.9173
# Epoch 147/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4372 - probability_loss: 0.2006 - bbox_regression_loss: 0.2365 - probability_accuracy: 0.9161
# Epoch 148/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4344 - probability_loss: 0.1993 - bbox_regression_loss: 0.2351 - probability_accuracy: 0.9173
# Epoch 149/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4368 - probability_loss: 0.2004 - bbox_regression_loss: 0.2364 - probability_accuracy: 0.9161
# Epoch 150/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4353 - probability_loss: 0.1996 - bbox_regression_loss: 0.2357 - probability_accuracy: 0.9149
# Epoch 151/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4357 - probability_loss: 0.1999 - bbox_regression_loss: 0.2358 - probability_accuracy: 0.9167
# Epoch 152/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4377 - probability_loss: 0.2006 - bbox_regression_loss: 0.2371 - probability_accuracy: 0.9155
# Epoch 153/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4345 - probability_loss: 0.1995 - bbox_regression_loss: 0.2350 - probability_accuracy: 0.9167
# Epoch 154/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4338 - probability_loss: 0.1988 - bbox_regression_loss: 0.2349 - probability_accuracy: 0.9173
# Epoch 155/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4339 - probability_loss: 0.1988 - bbox_regression_loss: 0.2351 - probability_accuracy: 0.9190
# Epoch 156/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4345 - probability_loss: 0.1995 - bbox_regression_loss: 0.2351 - probability_accuracy: 0.9155
# Epoch 157/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4333 - probability_loss: 0.1982 - bbox_regression_loss: 0.2351 - probability_accuracy: 0.9173
# Epoch 158/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4353 - probability_loss: 0.1995 - bbox_regression_loss: 0.2357 - probability_accuracy: 0.9155
# Epoch 159/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4325 - probability_loss: 0.1984 - bbox_regression_loss: 0.2341 - probability_accuracy: 0.9178
# Epoch 160/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4322 - probability_loss: 0.1982 - bbox_regression_loss: 0.2340 - probability_accuracy: 0.9184
# Epoch 161/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4334 - probability_loss: 0.1983 - bbox_regression_loss: 0.2351 - probability_accuracy: 0.9173
# Epoch 162/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4323 - probability_loss: 0.1979 - bbox_regression_loss: 0.2344 - probability_accuracy: 0.9184
# Epoch 163/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4330 - probability_loss: 0.1980 - bbox_regression_loss: 0.2350 - probability_accuracy: 0.9190
# Epoch 164/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4308 - probability_loss: 0.1973 - bbox_regression_loss: 0.2336 - probability_accuracy: 0.9184
# Epoch 165/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4319 - probability_loss: 0.1977 - bbox_regression_loss: 0.2342 - probability_accuracy: 0.9178
# Epoch 166/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4305 - probability_loss: 0.1968 - bbox_regression_loss: 0.2336 - probability_accuracy: 0.9184
# Epoch 167/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4313 - probability_loss: 0.1976 - bbox_regression_loss: 0.2337 - probability_accuracy: 0.9178
# Epoch 168/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4315 - probability_loss: 0.1973 - bbox_regression_loss: 0.2342 - probability_accuracy: 0.9208
# Epoch 169/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4307 - probability_loss: 0.1973 - bbox_regression_loss: 0.2334 - probability_accuracy: 0.9167
# Epoch 170/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4310 - probability_loss: 0.1971 - bbox_regression_loss: 0.2339 - probability_accuracy: 0.9173
# Epoch 171/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4294 - probability_loss: 0.1965 - bbox_regression_loss: 0.2329 - probability_accuracy: 0.9178
# Epoch 172/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4303 - probability_loss: 0.1967 - bbox_regression_loss: 0.2336 - probability_accuracy: 0.9184
# Epoch 173/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4289 - probability_loss: 0.1961 - bbox_regression_loss: 0.2328 - probability_accuracy: 0.9190
# Epoch 174/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4285 - probability_loss: 0.1959 - bbox_regression_loss: 0.2326 - probability_accuracy: 0.9178
# Epoch 175/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4276 - probability_loss: 0.1952 - bbox_regression_loss: 0.2324 - probability_accuracy: 0.9196
# Epoch 176/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4283 - probability_loss: 0.1956 - bbox_regression_loss: 0.2327 - probability_accuracy: 0.9178
# Epoch 177/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4271 - probability_loss: 0.1950 - bbox_regression_loss: 0.2321 - probability_accuracy: 0.9196
# Epoch 178/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4275 - probability_loss: 0.1953 - bbox_regression_loss: 0.2322 - probability_accuracy: 0.9190
# Epoch 179/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4271 - probability_loss: 0.1954 - bbox_regression_loss: 0.2317 - probability_accuracy: 0.9190
# Epoch 180/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4300 - probability_loss: 0.1964 - bbox_regression_loss: 0.2335 - probability_accuracy: 0.9190
# Epoch 181/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4271 - probability_loss: 0.1945 - bbox_regression_loss: 0.2326 - probability_accuracy: 0.9184
# Epoch 182/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4260 - probability_loss: 0.1944 - bbox_regression_loss: 0.2316 - probability_accuracy: 0.9184
# Epoch 183/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4267 - probability_loss: 0.1947 - bbox_regression_loss: 0.2320 - probability_accuracy: 0.9196
# Epoch 184/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4263 - probability_loss: 0.1945 - bbox_regression_loss: 0.2318 - probability_accuracy: 0.9184
# Epoch 185/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4247 - probability_loss: 0.1936 - bbox_regression_loss: 0.2311 - probability_accuracy: 0.9202
# Epoch 186/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4258 - probability_loss: 0.1946 - bbox_regression_loss: 0.2312 - probability_accuracy: 0.9196
# Epoch 187/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.
350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4124 - probability_loss: 0.1864 - bbox_regression_loss: 0.2260 - probability_accuracy: 0.9237
# Epoch 241/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4099 - probability_loss: 0.1853 - bbox_regression_loss: 0.2245 - probability_accuracy: 0.9225
# Epoch 242/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4104 - probability_loss: 0.1854 - bbox_regression_loss: 0.2250 - probability_accuracy: 0.9243
# Epoch 243/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4101 - probability_loss: 0.1853 - bbox_regression_loss: 0.2248 - probability_accuracy: 0.9208
# Epoch 244/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4093 - probability_loss: 0.1853 - bbox_regression_loss: 0.2240 - probability_accuracy: 0.9225
# Epoch 245/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4100 - probability_loss: 0.1855 - bbox_regression_loss: 0.2245 - probability_accuracy: 0.9219
# Epoch 246/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4084 - probability_loss: 0.1844 - bbox_regression_loss: 0.2240 - probability_accuracy: 0.9219
# Epoch 247/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4082 - probability_loss: 0.1843 - bbox_regression_loss: 0.2239 - probability_accuracy: 0.9214
# Epoch 248/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4094 - probability_loss: 0.1846 - bbox_regression_loss: 0.2248 - probability_accuracy: 0.9261
# Epoch 249/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4075 - probability_loss: 0.1841 - bbox_regression_loss: 0.2233 - probability_accuracy: 0.9219
# Epoch 250/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4066 - probability_loss: 0.1837 - bbox_regression_loss: 0.2229 - probability_accuracy: 0.9237
# Epoch 251/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4074 - probability_loss: 0.1841 - bbox_regression_loss: 0.2234 - probability_accuracy: 0.9237
# Epoch 252/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4103 - probability_loss: 0.1854 - bbox_regression_loss: 0.2249 - probability_accuracy: 0.9243
# Epoch 253/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4067 - probability_loss: 0.1833 - bbox_regression_loss: 0.2234 - probability_accuracy: 0.9243
# Epoch 254/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4083 - probability_loss: 0.1842 - bbox_regression_loss: 0.2241 - probability_accuracy: 0.9219
# Epoch 255/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4078 - probability_loss: 0.1839 - bbox_regression_loss: 0.2238 - probability_accuracy: 0.9237
# Epoch 256/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4074 - probability_loss: 0.1834 - bbox_regression_loss: 0.2240 - probability_accuracy: 0.9231
# Epoch 257/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4091 - probability_loss: 0.1845 - bbox_regression_loss: 0.2246 - probability_accuracy: 0.9219
# Epoch 258/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4065 - probability_loss: 0.1837 - bbox_regression_loss: 0.2228 - probability_accuracy: 0.9249
# Epoch 259/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4050 - probability_loss: 0.1826 - bbox_regression_loss: 0.2224 - probability_accuracy: 0.9266
# Epoch 260/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4053 - probability_loss: 0.1825 - bbox_regression_loss: 0.2228 - probability_accuracy: 0.9237
# Epoch 261/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4030 - probability_loss: 0.1822 - bbox_regression_loss: 0.2209 - probability_accuracy: 0.9231
# Epoch 262/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4040 - probability_loss: 0.1822 - bbox_regression_loss: 0.2218 - probability_accuracy: 0.9249
# Epoch 263/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4039 - probability_loss: 0.1819 - bbox_regression_loss: 0.2220 - probability_accuracy: 0.9272
# Epoch 264/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4044 - probability_loss: 0.1824 - bbox_regression_loss: 0.2220 - probability_accuracy: 0.9225
# Epoch 265/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4042 - probability_loss: 0.1817 - bbox_regression_loss: 0.2225 - probability_accuracy: 0.9255
# Epoch 266/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4032 - probability_loss: 0.1812 - bbox_regression_loss: 0.2220 - probability_accuracy: 0.9237
# Epoch 267/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4034 - probability_loss: 0.1818 - bbox_regression_loss: 0.2217 - probability_accuracy: 0.9231
# Epoch 268/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4034 - probability_loss: 0.1815 - bbox_regression_loss: 0.2219 - probability_accuracy: 0.9249
# Epoch 269/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4029 - probability_loss: 0.1811 - bbox_regression_loss: 0.2218 - probability_accuracy: 0.9249
# Epoch 270/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4012 - probability_loss: 0.1803 - bbox_regression_loss: 0.2210 - probability_accuracy: 0.9255
# Epoch 271/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4050 - probability_loss: 0.1823 - bbox_regression_loss: 0.2227 - probability_accuracy: 0.9278
# Epoch 272/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4020 - probability_loss: 0.1807 - bbox_regression_loss: 0.2213 - probability_accuracy: 0.9249
# Epoch 273/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4027 - probability_loss: 0.1811 - bbox_regression_loss: 0.2216 - probability_accuracy: 0.9219
# Epoch 274/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4012 - probability_loss: 0.1807 - bbox_regression_loss: 0.2205 - probability_accuracy: 0.9261
# Epoch 275/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4001 - probability_loss: 0.1801 - bbox_regression_loss: 0.2200 - probability_accuracy: 0.9237
# Epoch 276/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4019 - probability_loss: 0.1809 - bbox_regression_loss: 0.2210 - probability_accuracy: 0.9266
# Epoch 277/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4008 - probability_loss: 0.1803 - bbox_regression_loss: 0.2205 - probability_accuracy: 0.9266
# Epoch 278/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4013 - probability_loss: 0.1804 - bbox_regression_loss: 0.2209 - probability_accuracy: 0.9261
# Epoch 279/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4012 - probability_loss: 0.1800 - bbox_regression_loss: 0.2212 - probability_accuracy: 0.9266
# Epoch 280/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4022 - probability_loss: 0.1806 - bbox_regression_loss: 0.2216 - probability_accuracy: 0.9243
# Epoch 281/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4015 - probability_loss: 0.1801 - bbox_regression_loss: 0.2214 - probability_accuracy: 0.9261
# Epoch 282/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3981 - probability_loss: 0.1790 - bbox_regression_loss: 0.2191 - probability_accuracy: 0.9272
# Epoch 283/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4001 - probability_loss: 0.1800 - bbox_regression_loss: 0.2201 - probability_accuracy: 0.9255
# Epoch 284/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.4002 - probability_loss: 0.1794 - bbox_regression_loss: 0.2208 - probability_accuracy: 0.9278
# Epoch 285/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3974 - probability_loss: 0.1785 - bbox_regression_loss: 0.2189 - probability_accuracy: 0.9249
# Epoch 286/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3982 - probability_loss: 0.1785 - bbox_regression_loss: 0.2196 - probability_accuracy: 0.9272
# Epoch 287/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3958 - probability_loss: 0.1773 - bbox_regression_loss: 0.2186 - probability_accuracy: 0.9319
# Epoch 288/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3972 - probability_loss: 0.1780 - bbox_regression_loss: 0.2192 - probability_accuracy: 0.9272
# Epoch 289/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3972 - probability_loss: 0.1781 - bbox_regression_loss: 0.2191 - probability_accuracy: 0.9278
# Epoch 290/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3973 - probability_loss: 0.1782 - bbox_regression_loss: 0.2191 - probability_accuracy: 0.9296
# Epoch 291/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3971 - probability_loss: 0.1779 - bbox_regression_loss: 0.2192 - probability_accuracy: 0.9296
# Epoch 292/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3954 - probability_loss: 0.1771 - bbox_regression_loss: 0.2183 - probability_accuracy: 0.9278
# Epoch 293/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.
350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3905 - probability_loss: 0.1743 - bbox_regression_loss: 0.2162 - probability_accuracy: 0.9278
# Epoch 320/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3890 - probability_loss: 0.1734 - bbox_regression_loss: 0.2156 - probability_accuracy: 0.9272
# Epoch 321/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3881 - probability_loss: 0.1730 - bbox_regression_loss: 0.2151 - probability_accuracy: 0.9313
# Epoch 322/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3892 - probability_loss: 0.1734 - bbox_regression_loss: 0.2157 - probability_accuracy: 0.9308
# Epoch 323/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3887 - probability_loss: 0.1733 - bbox_regression_loss: 0.2154 - probability_accuracy: 0.9302
# Epoch 324/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3880 - probability_loss: 0.1732 - bbox_regression_loss: 0.2148 - probability_accuracy: 0.9308
# Epoch 325/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3879 - probability_loss: 0.1726 - bbox_regression_loss: 0.2153 - probability_accuracy: 0.9302
# Epoch 326/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3882 - probability_loss: 0.1731 - bbox_regression_loss: 0.2151 - probability_accuracy: 0.9284
# Epoch 327/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3873 - probability_loss: 0.1725 - bbox_regression_loss: 0.2148 - probability_accuracy: 0.9331
# Epoch 328/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3868 - probability_loss: 0.1725 - bbox_regression_loss: 0.2143 - probability_accuracy: 0.9290
# Epoch 329/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3862 - probability_loss: 0.1719 - bbox_regression_loss: 0.2143 - probability_accuracy: 0.9308
# Epoch 330/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3869 - probability_loss: 0.1723 - bbox_regression_loss: 0.2146 - probability_accuracy: 0.9296
# Epoch 331/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3884 - probability_loss: 0.1732 - bbox_regression_loss: 0.2153 - probability_accuracy: 0.9313
# Epoch 332/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3862 - probability_loss: 0.1720 - bbox_regression_loss: 0.2141 - probability_accuracy: 0.9313
# Epoch 333/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3846 - probability_loss: 0.1714 - bbox_regression_loss: 0.2132 - probability_accuracy: 0.9319
# Epoch 334/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3848 - probability_loss: 0.1715 - bbox_regression_loss: 0.2133 - probability_accuracy: 0.9331
# Epoch 335/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3862 - probability_loss: 0.1718 - bbox_regression_loss: 0.2145 - probability_accuracy: 0.9302
# Epoch 336/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3848 - probability_loss: 0.1709 - bbox_regression_loss: 0.2139 - probability_accuracy: 0.9319
# Epoch 337/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3849 - probability_loss: 0.1712 - bbox_regression_loss: 0.2137 - probability_accuracy: 0.9284
# Epoch 338/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3859 - probability_loss: 0.1722 - bbox_regression_loss: 0.2138 - probability_accuracy: 0.9319
# Epoch 339/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3864 - probability_loss: 0.1720 - bbox_regression_loss: 0.2144 - probability_accuracy: 0.9278
# Epoch 340/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3842 - probability_loss: 0.1708 - bbox_regression_loss: 0.2133 - probability_accuracy: 0.9296
# Epoch 341/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3853 - probability_loss: 0.1714 - bbox_regression_loss: 0.2139 - probability_accuracy: 0.9302
# Epoch 342/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3853 - probability_loss: 0.1717 - bbox_regression_loss: 0.2136 - probability_accuracy: 0.9290
# Epoch 343/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3827 - probability_loss: 0.1696 - bbox_regression_loss: 0.2131 - probability_accuracy: 0.9331
# Epoch 344/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3854 - probability_loss: 0.1721 - bbox_regression_loss: 0.2133 - probability_accuracy: 0.9284
# Epoch 345/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3824 - probability_loss: 0.1697 - bbox_regression_loss: 0.2127 - probability_accuracy: 0.9319
# Epoch 346/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3829 - probability_loss: 0.1699 - bbox_regression_loss: 0.2130 - probability_accuracy: 0.9313
# Epoch 347/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3827 - probability_loss: 0.1699 - bbox_regression_loss: 0.2128 - probability_accuracy: 0.9302
# Epoch 348/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3819 - probability_loss: 0.1697 - bbox_regression_loss: 0.2122 - probability_accuracy: 0.9319
# Epoch 349/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3833 - probability_loss: 0.1701 - bbox_regression_loss: 0.2132 - probability_accuracy: 0.9296
# Epoch 350/350
# 107/107 [==============================] - 0s 2ms/step - loss: 0.3820 - probability_loss: 0.1695 - bbox_regression_loss: 0.2125 - probability_accuracy: 0.9313

# %% [markdown]
# # Test P-Net proposals

# %%
def __nms(boxes, s, threshold, method):
    """
        Non Maximum Suppression.

        Params:
            @param boxes: np array with bounding boxes.
            @param threshold:
            @param method: NMS method to apply. Available values ('Min', 'Union')
        
        Return:
            pick : An array of indices selected.
    """
    if boxes.size == 0:
        return np.empty((0, 3))

    x1 = boxes[:, 0]
    y1 = boxes[:, 1]
    x2 = boxes[:, 2]
    y2 = boxes[:, 3]

    area = (x2 - x1 + 1) * (y2 - y1 + 1)
    sorted_s = np.argsort(s)

    pick = np.zeros_like(s, dtype=np.int16)
    counter = 0
    while sorted_s.size > 0:
        i = sorted_s[-1]
        pick[counter] = i
        counter += 1
        idx = sorted_s[0:-1]

        xx1 = np.maximum(x1[i], x1[idx])
        yy1 = np.maximum(y1[i], y1[idx])
        xx2 = np.minimum(x2[i], x2[idx])
        yy2 = np.minimum(y2[i], y2[idx])

        w = np.maximum(0.0, xx2 - xx1 + 1)
        h = np.maximum(0.0, yy2 - yy1 + 1)

        inter = w * h

        if method == 'Min':
            o = inter / np.minimum(area[i], area[idx])
        else:
            o = inter / (area[i] + area[idx] - inter)

        sorted_s = sorted_s[np.where(o <= threshold)]

    pick = pick[0:counter]

    return pick

# %%
threshold = 0.95
nms_threshold = 0.5
raw_img = cv2.imread('test.png')
img = (raw_img - 127.5) / 127.5
height, width = img.shape[:2]

bboxes = pnet.predict(np.array([img]))[1][0]
confidence = pnet.predict(np.array([img]))[0][0]

bboxes = bboxes.reshape(bboxes.shape[0] * bboxes.shape[1], 4)
confidence = confidence.reshape(confidence.shape[0] * confidence.shape[1], 2)
confidence = confidence[:,1].astype('float')

candidate_windows = bboxes[confidence > threshold]
confidence = confidence[confidence > threshold]

boxes = []
for window in candidate_windows:
    x1, y1, w, h = np.multiply(window, np.array([width, height, width, height])).astype('int')
    boxes.append([x1, y1, w, h])   

pick = __nms(np.array(boxes), confidence, nms_threshold, 'Min')
for i in pick:
    x,y,w,h = boxes[i]
    cv2.rectangle(raw_img, (x,y), (x+w, y+h), (0,255,0),2)

plt.imshow(raw_img)
plt.show()
# Out:
# <ipython-input-80-b43c0dc23759>:40: RuntimeWarning: invalid value encountered in true_divide
#   o = inter / np.minimum(area[i], area[idx])
# <ipython-input-80-b43c0dc23759>:44: RuntimeWarning: invalid value encountered in less_equal
#   sorted_s = sorted_s[np.where(o <= threshold)]
